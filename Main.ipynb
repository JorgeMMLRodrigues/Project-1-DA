# %%
import requests
from dotenv import load_dotenv
import os
import json
import pandas as pd
import time
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
load_dotenv('.env')
# Out:
# True

# %%
headers = {
	"x-rapidapi-key": os.getenv("x-rapidapi-key"),
	"x-rapidapi-host": "transfermarkt6.p.rapidapi.com"
}

# %% [markdown]
# ### Get Players Performance 2022

# %%
def getplayersperformance():

    leagues = ['GB1', 'ES1', 'IT1', 'FR1', 'L1']


    url = "https://transfermarkt6.p.rapidapi.com/competitions/players-performance"


    filename = "getplayersperformance.json"

    if os.path.exists(filename):

        with open(filename, "r", encoding="utf-8") as f:
            existing_data = json.load(f)
            if not isinstance(existing_data, dict):
                existing_data = {}
    else:
        existing_data = {}


    for league in leagues:

        querystring = {"id": league, "seasonId": "2024"} 

        response = requests.get(url, headers=headers, params=querystring)

        data = response.json()
        existing_data[league] = data

        time.sleep(2)

    with open(filename, "w", encoding="utf-8") as f:
        json.dump(existing_data, f, indent=4, ensure_ascii=False)

getplayersperformance()

# %%
getplayersperformance_2022 = "getplayersperformance_2022.json"

def read_json_old(json_variable):

    with open('getplayersperformance_2022.json', 'r') as file:
        getplayersperformance_dict_2022 = json.load(file)

    return getplayersperformance_dict_2022

getplayersperformance_dict_2022 = read_json_old(getplayersperformance_2022)

# %%
df_GB1 = getplayersperformance_dict_2022['GB1']['data']['player']

df_ES1 = getplayersperformance_dict_2022['ES1']['data']['player']

df_FR1 = getplayersperformance_dict_2022['FR1']['data']['player']

df_IT1 = getplayersperformance_dict_2022['IT1']['data']['player']

df_L1 = getplayersperformance_dict_2022['L1']['data']['player']

df_GB1 = pd.DataFrame(df_GB1)

df_ES1 = pd.DataFrame(df_ES1)

df_FR1 = pd.DataFrame(df_FR1)

df_IT1 = pd.DataFrame(df_IT1)

df_L1 = pd.DataFrame(df_L1)

# %%
df_players_combined_2022 = pd.concat([df_GB1, df_ES1, df_FR1, df_IT1, df_L1], ignore_index=True)

df_players_combined_2022
# Out:
#       clubID  numberOfClubs  superSubStrikes      id  matches  goals  assists  \
# 0         31              1                0    3333       31      0        1
# 1        985              1                1    8198       10      1        0
# 2        405              1                0   14086       29      1        0
# 3        985              1                0   16306       28      4        3
# 4        148              1                0   17965       25      0        0
# ...      ...            ...              ...     ...      ...    ...      ...
# 2800      44              1                0  820261        1      0        0
# 2801      44              1                1  820957       10      1        0
# 2802     533              1                0  822959       11      0        1
# 2803      27              1                0  900909        2      0        0
# 2804      44              1                1  905011        2      1        0
#
#       scorer  yellowCards  yellowRedCards  redCards  penalty  ownGoals  \
# 0          1            2               0         0        0         0
# 1          1            2               0         0        0         0
# 2          1            7               0         0        0         0
# 3          7            7               0         2        0         0
# 4          0            0               0         0        0         1
# ...      ...          ...             ...       ...      ...       ...
# 2800       0            0               0         0        0         0
# 2801       1            0               0         0        0         0
# 2802       1            0               0         0        0         0
# 2803       0            1               0         0        0         0
# 2804       1            0               0         0        0         0
#
#       starting  substitutedOff  substitutedOn  minutesPlayed  minutesPerGoal  \
# 0            7               4             24            893               0
# 1            4               1              6            520             520
# 2           23               8              6           2038               2
# 3           24               4              4           2127             532
# 4           25               1              0           2205               0
# ...        ...             ...            ...            ...             ...
# 2800         1               0              0             90               0
# 2801         2               2              8            279             279
# 2802         3               3              8            310               0
# 2803         0               0              2             23               0
# 2804         0               0              2             70              70
#
#       goalsPerMatch
# 0              0.00
# 1              0.10
# 2              0.03
# 3              0.14
# 4              0.00
# ...             ...
# 2800           0.00
# 2801           0.10
# 2802           0.00
# 2803           0.00
# 2804           0.50
#
# [2805 rows x 19 columns]

# %% [markdown]
# ### Get Players Performance 2024

# %%
def getplayersperformance():

    leagues = ['GB1', 'ES1', 'IT1', 'FR1', 'L1']


    url = "https://transfermarkt6.p.rapidapi.com/competitions/players-performance"


    filename = "getplayersperformance.json"

    if os.path.exists(filename):

        with open(filename, "r", encoding="utf-8") as f:
            existing_data = json.load(f)
            if not isinstance(existing_data, dict):
                existing_data = {}
    else:
        existing_data = {}


    for league in leagues:

        querystring = {"id": league, "seasonId": "2024"} 

        response = requests.get(url, headers=headers, params=querystring)

        data = response.json()
        existing_data[league] = data

        time.sleep(2)

    with open(filename, "w", encoding="utf-8") as f:
        json.dump(existing_data, f, indent=4, ensure_ascii=False)

getplayersperformance()

# %%
getplayersperformance_2024 = "getplayersperformance_2024.json"

def read_json_old(json_variable):

    with open('getplayersperformance_2024.json', 'r') as file:
        getplayersperformance_dict_2024 = json.load(file)

    return getplayersperformance_dict_2024

getplayersperformance_dict_2024 = read_json_old(getplayersperformance_2024)

# %%
df1_GB1 = getplayersperformance_dict_2024['GB1']['data']['player']

df1_ES1 = getplayersperformance_dict_2024['ES1']['data']['player']

df1_FR1 = getplayersperformance_dict_2024['FR1']['data']['player']

df1_IT1 = getplayersperformance_dict_2024['IT1']['data']['player']

df1_L1 = getplayersperformance_dict_2024['L1']['data']['player']

df1_GB1 = pd.DataFrame(df1_GB1)

df1_ES1 = pd.DataFrame(df1_ES1)

df1_FR1 = pd.DataFrame(df1_FR1)

df1_IT1 = pd.DataFrame(df1_IT1)

df1_L1 = pd.DataFrame(df1_L1)

# %%
df_players_combined_2024 = pd.concat([df1_GB1, df1_ES1, df1_FR1, df1_IT1, df1_L1], ignore_index=True)

df_players_combined_2024
# Out:
#       clubID  numberOfClubs  superSubStrikes       id  matches  goals  \
# 0       1237              1                0     3333        3      0
# 1         29              1                0    14086       23      1
# 2        985              1                0    16306       16      1
# 3        379              1                0    29692       13      0
# 4        985              1                0    42412        6      0
# ...      ...            ...              ...      ...      ...    ...
# 2639     533              1                0  1067904        2      0
# 2640      18              1                1  1073997        3      1
# 2641   23826              1                0  1074526        1      0
# 2642   23826              1                0  1132292        1      0
# 2643      35              1                0  1280281        5      0
#
#       assists  scorer  yellowCards  yellowRedCards  redCards  penalty  \
# 0           0       0            1               0         0        0
# 1           3       4            6               0         1        0
# 2           0       1            2               0         0        0
# 3           0       0            2               0         0        0
# 4           0       0            1               0         0        0
# ...       ...     ...          ...             ...       ...      ...
# 2639        0       0            0               0         0        0
# 2640        0       1            0               0         0        0
# 2641        0       0            0               0         0        0
# 2642        0       0            0               0         0        0
# 2643        0       0            0               0         0        0
#
#       ownGoals  starting  substitutedOff  substitutedOn  minutesPlayed  \
# 0            0         3               3              0            172
# 1            0        17               4              6           1541
# 2            0        12               8              4            990
# 3            0        12               1              1           1071
# 4            0         3               2              3            290
# ...        ...       ...             ...            ...            ...
# 2639         0         0               0              2             24
# 2640         0         0               0              3             24
# 2641         0         0               0              1             13
# 2642         0         0               0              1              1
# 2643         0         0               0              5             31
#
#       minutesPerGoal  goalsPerMatch
# 0                  0           0.00
# 1                  1           0.04
# 2                990           0.06
# 3                  0           0.00
# 4                  0           0.00
# ...              ...            ...
# 2639               0           0.00
# 2640              24           0.33
# 2641               0           0.00
# 2642               0           0.00
# 2643               0           0.00
#
# [2644 rows x 19 columns]

# %% [markdown]
# ### Clean 2022 and 2024 datsets

# %%
df_players_combined_2024

df_players_combined_2022
# Out:
#       clubID  numberOfClubs  superSubStrikes  player_id  matches  goals  \
# 0         31              1                0       3333       31      0
# 1        985              1                1       8198       10      1
# 2        405              1                0      14086       29      1
# 3        985              1                0      16306       28      4
# 4        148              1                0      17965       25      0
# ...      ...            ...              ...        ...      ...    ...
# 2800      44              1                0     820261        1      0
# 2801      44              1                1     820957       10      1
# 2802     533              1                0     822959       11      0
# 2803      27              1                0     900909        2      0
# 2804      44              1                1     905011        2      1
#
#       assists  scorer  yellowCards  yellowRedCards  redCards  penalty  \
# 0           1       1            2               0         0        0
# 1           0       1            2               0         0        0
# 2           0       1            7               0         0        0
# 3           3       7            7               0         2        0
# 4           0       0            0               0         0        0
# ...       ...     ...          ...             ...       ...      ...
# 2800        0       0            0               0         0        0
# 2801        0       1            0               0         0        0
# 2802        1       1            0               0         0        0
# 2803        0       0            1               0         0        0
# 2804        0       1            0               0         0        0
#
#       ownGoals  starting  substitutedOff  substitutedOn  minutesPlayed  \
# 0            0         7               4             24            893
# 1            0         4               1              6            520
# 2            0        23               8              6           2038
# 3            0        24               4              4           2127
# 4            1        25               1              0           2205
# ...        ...       ...             ...            ...            ...
# 2800         0         1               0              0             90
# 2801         0         2               2              8            279
# 2802         0         3               3              8            310
# 2803         0         0               0              2             23
# 2804         0         0               0              2             70
#
#       minutesPerGoal  goalsPerMatch
# 0                  0           0.00
# 1                520           0.10
# 2                  2           0.03
# 3                532           0.14
# 4                  0           0.00
# ...              ...            ...
# 2800               0           0.00
# 2801             279           0.10
# 2802               0           0.00
# 2803               0           0.00
# 2804              70           0.50
#
# [2805 rows x 19 columns]

# %%
def add_underscore_before_caps(col_name):
    return re.sub(r'([A-Z])', r'_\1', col_name).lower().lstrip('_')


df_players_combined_2022.columns = [add_underscore_before_caps(col) for col in df_players_combined_2022.columns]

# %%
df_players_combined_2022.rename(columns={'id': 'player_id'}, inplace=True)

# %%
df_players_combined_2022 = df_players_combined_2022[['player_id', 'goals', 'assists', 'minutes_played']]

# %%
df_players_combined_2022
# Out:
#       player_id  goals  assists  minutes_played
# 0          3333      0        1             893
# 1          8198      1        0             520
# 2         14086      1        0            2038
# 3         16306      4        3            2127
# 4         17965      0        0            2205
# ...         ...    ...      ...             ...
# 2800     820261      0        0              90
# 2801     820957      1        0             279
# 2802     822959      0        1             310
# 2803     900909      0        0              23
# 2804     905011      1        0              70
#
# [2805 rows x 4 columns]

# %%
def add_underscore_before_caps(col_name):
    return re.sub(r'([A-Z])', r'_\1', col_name).lower().lstrip('_')


df_players_combined_2024.columns = [add_underscore_before_caps(col) for col in df_players_combined_2024.columns]

# %%
df_players_combined_2024.rename(columns={'id': 'player_id'}, inplace=True)

# %%
df_players_combined_2024 = df_players_combined_2024[['player_id', 'goals', 'assists', 'minutes_played']]

# %%
df_players_combined_2024
# Out:
#       player_id  goals  assists  minutes_played  minutes_per_g_a
# 0         14086      1        3            1541           385.25
# 1         16306      1        0             990           990.00
# 2         43530      0        2             336           168.00
# 3         51471      4        1            1565           313.00
# 4         53622      0        2            1445           722.50
# ...         ...    ...      ...             ...              ...
# 1479     931838      3        0            1613           537.67
# 1480     939964      0        2             311           155.50
# 1481     977464      0        1             428           428.00
# 1482    1018259      4        0             365            91.25
# 1483    1073997      1        0              24            24.00
#
# [1484 rows x 5 columns]

# %%
df_players_combined_2022.dtypes
df_players_combined_2024.dtypes
# Out:
# player_id         int64
# goals             int64
# assists           int64
# minutes_played    int64
# dtype: object

# %%
df_players_combined_2022.isna().sum()
df_players_combined_2024.isna().sum()
# Out:
# player_id         0
# goals             0
# assists           0
# minutes_played    0
# dtype: int64

# %%
df_players_combined_2022.duplicated().sum()
df_players_combined_2024.duplicated().sum()
# Out:
# 1

# %% [markdown]
# ### Goal Contribution Efficiency Column 2024

# %%
df_players_combined_2024

df_players_combined_2022
# Out:
#       player_id  goals  assists  minutes_played
# 0          3333      0        1             893
# 1          8198      1        0             520
# 2         14086      1        0            2038
# 3         16306      4        3            2127
# 4         17965      0        0            2205
# ...         ...    ...      ...             ...
# 2800     820261      0        0              90
# 2801     820957      1        0             279
# 2802     822959      0        1             310
# 2803     900909      0        0              23
# 2804     905011      1        0              70
#
# [2805 rows x 4 columns]

# %%
def goal_contribution_efficiency(data_set):

    def calculate_efficiency(row):

        if row['goals'] + row['assists'] > 0 and row['minutes_played'] > 0: 

            return round(row['minutes_played'] / (row['goals'] + row['assists']),2)
        
        else:

            return np.nan 

    
    data_set['minutes_per_g_a'] = data_set.apply(calculate_efficiency, axis=1)

    return data_set

# %%
goal_contribution_efficiency(df_players_combined_2024)
# Out:
# C:\Users\estif\AppData\Local\Temp\ipykernel_16360\3507742405.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_set['minutes_per_g_a'] = data_set.apply(calculate_efficiency, axis=1)
#       player_id  goals  assists  minutes_played  minutes_per_g_a
# 0          3333      0        0             172              NaN
# 1         14086      1        3            1541           385.25
# 2         16306      1        0             990           990.00
# 3         29692      0        0            1071              NaN
# 4         42412      0        0             290              NaN
# ...         ...    ...      ...             ...              ...
# 2639    1067904      0        0              24              NaN
# 2640    1073997      1        0              24            24.00
# 2641    1074526      0        0              13              NaN
# 2642    1132292      0        0               1              NaN
# 2643    1280281      0        0              31              NaN
#
# [2644 rows x 5 columns]

# %%
df_players_combined_2024 = df_players_combined_2024.dropna()

# %%
df_players_combined_2024 = df_players_combined_2024.reset_index(drop=True)

# %%
df_players_combined_2024
# Out:
#       player_id  goals  assists  minutes_played  minutes_per_g_a
# 0         14086      1        3            1541           385.25
# 1         16306      1        0             990           990.00
# 2         43530      0        2             336           168.00
# 3         51471      4        1            1565           313.00
# 4         53622      0        2            1445           722.50
# ...         ...    ...      ...             ...              ...
# 1479     931838      3        0            1613           537.67
# 1480     939964      0        2             311           155.50
# 1481     977464      0        1             428           428.00
# 1482    1018259      4        0             365            91.25
# 1483    1073997      1        0              24            24.00
#
# [1484 rows x 5 columns]

# %%
df_players_combined_2024 = pd.read_csv('df_players_combined_2024.csv')

# %% [markdown]
# ### Goal Contribution Efficiency Column 2022

# %%
goal_contribution_efficiency(df_players_combined_2022)
# Out:
# C:\Users\estif\AppData\Local\Temp\ipykernel_16360\3507742405.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_set['minutes_per_g_a'] = data_set.apply(calculate_efficiency, axis=1)
#       player_id  goals  assists  minutes_played  minutes_per_g_a
# 0          3333      0        1             893           893.00
# 1          8198      1        0             520           520.00
# 2         14086      1        0            2038          2038.00
# 3         16306      4        3            2127           303.86
# 4         17965      0        0            2205              NaN
# ...         ...    ...      ...             ...              ...
# 2800     820261      0        0              90              NaN
# 2801     820957      1        0             279           279.00
# 2802     822959      0        1             310           310.00
# 2803     900909      0        0              23              NaN
# 2804     905011      1        0              70            70.00
#
# [2805 rows x 5 columns]

# %%
df_players_combined_2022 = df_players_combined_2022.dropna()

# %%
df_players_combined_2022 = df_players_combined_2022.reset_index(drop=True)

# %%
# How to drop them
# df_players_combined_2022 = df_players_combined_2022.drop(columns=['index'])

# %%
df_players_combined_2022
# Out:
#       player_id  goals  assists  minutes_played  minutes_per_g_a
# 0          3333      0        1             893           893.00
# 1          8198      1        0             520           520.00
# 2         14086      1        0            2038          2038.00
# 3         16306      4        3            2127           303.86
# 4         29241      0        2            2352          1176.00
# ...         ...    ...      ...             ...              ...
# 1748     798043      0        1              24            24.00
# 1749     801734      5        0             397            79.40
# 1750     820957      1        0             279           279.00
# 1751     822959      0        1             310           310.00
# 1752     905011      1        0              70            70.00
#
# [1753 rows x 5 columns]

# %%
df_players_combined_2022 = pd.read_csv('df_players_combined_2022.csv')

# %%
df_players_combined_2022
# Out:
#       player_id  goals  assists  minutes_played  minutes_per_g_a
# 0          3333      0        1             893           893.00
# 1          8198      1        0             520           520.00
# 2         14086      1        0            2038          2038.00
# 3         16306      4        3            2127           303.86
# 4         29241      0        2            2352          1176.00
# ...         ...    ...      ...             ...              ...
# 1748     798043      0        1              24            24.00
# 1749     801734      5        0             397            79.40
# 1750     820957      1        0             279           279.00
# 1751     822959      0        1             310           310.00
# 1752     905011      1        0              70            70.00
#
# [1753 rows x 5 columns]

# %% [markdown]
# ### Top 5 players for 2024

# %%
df_top5_2024 = df_players_combined_2024

# %%
df_top5_2024 = df_top5_2024[(df_top5_2024['minutes_played'] > 1000)]

# %%
df_top5_2024['minutes_played'].mean()
# Out:
# 1582.9954853273139

# %%
df_top5_2024 = df_top5_2024[(df_top5_2024['minutes_played'] > 1582)]

# %%
df_top5_2024 = df_top5_2024.sort_values(by='minutes_per_g_a', ascending=True)

# %%
df_top5_2024 = df_top5_2024.reset_index(drop=True)

# %%
df_top5_2024 = df_top5_2024.head(5)

# %%
df_top5_2024
# Out:
#    player_id  goals  assists  minutes_played  minutes_per_g_a
# 0     132098     21        8            1648            56.83
# 1     148455     25       16            2395            58.41
# 2     349066     19        5            1984            82.67
# 3      38253     20        2            1927            87.59
# 4     598577      9       11            1784            89.20

# %% [markdown]
# ### Top 5 players for 2022

# %%
df_top5_2022 = df_players_combined_2022

# %%
df_top5_2022 = df_top5_2022[(df_top5_2022['minutes_played'] > 1000)]

# %%
df_top5_2022['minutes_played'].mean()
# Out:
# 2045.145299145299

# %%
df_top5_2022 = df_top5_2022[(df_top5_2022['minutes_played'] > 2045)]

# %%
df_top5_2022 = df_top5_2022.sort_values(by='minutes_per_g_a', ascending=True)

# %%
df_top5_2022 = df_top5_2022.reset_index(drop=True)

# %%
df_top5_2022 = df_top5_2022.head(5)

# %%
df_top5_2022
# Out:
#    player_id  goals  assists  minutes_played  minutes_per_g_a
# 0     418560     36        8            2777            63.11
# 1     342229     29        6            2822            80.63
# 2     401923     26        5            2581            83.26
# 3     146854     19        6            2128            85.12
# 4     580195     12       13            2211            88.44

# %% [markdown]
# ### Players Profile Info 2022

# %%
list_top5_2022_ids = list(df_top5_2022['player_id'])
list_top5_2024_ids = list(df_top5_2024['player_id'])

# %%
list_top5_2022_ids
# Out:
# [418560, 342229, 401923, 146854, 580195]

# %%
list_top5_2024_ids
# Out:
# [132098, 148455, 349066, 38253, 598577]

# %%
def getplayersinfo(df_players_ids):

    url = "https://transfermarkt6.p.rapidapi.com/players/profile"


    filename = "getplayersinfo.json"

    if os.path.exists(filename):

        with open(filename, "r", encoding="utf-8") as f:
            existing_data = json.load(f)
            if not isinstance(existing_data, dict):
                existing_data = {}
    else:
        existing_data = {}


    for id in df_players_ids:

        querystring = {"id":id}

        response = requests.get(url, headers=headers, params=querystring)

        data = response.json()
        existing_data[id] = data

        time.sleep(2)

    with open(filename, "w", encoding="utf-8") as f:
        json.dump(existing_data, f, indent=4, ensure_ascii=False)


    response = requests.get(url, headers=headers, params=querystring)

# %%
getplayersinfo(list_top5_2022_ids)

# %%
def read_json_ALL(json_filename):
    with open(json_filename, 'r') as file:
        data = json.load(file)
    return data

# %%
getplayersinfo_2022 = read_json_ALL("getplayersinfo_2022.json")

# %%
getplayersinfo_2022
# Out:
# {'418560': {'data': {'share': {'title': 'Erling Haaland - Spielerprofil',
#     'url': 'https://www.transfermarkt.de/erling-haaland/profil/spieler/418560',
#     'description': 'Das ist das Spielerprofil von Erling Haaland.'},
#    'playerProfile': {'playerID': '418560',
#     'playerImage': 'https://img.a.transfermarkt.technology/portrait/medium/418560-1709108116.png?lm=1',
#     'playerName': 'Erling Haaland',
#     'playerFullName': 'Erling Haaland',
#     'birthplace': 'Leeds',
#     'dateOfBirth': '21.07.2000',
#     'dateOfDeath': None,
#     'playerShirtNumber': '9',
#     'birthplaceCountry': 'England',
#     'birthplaceCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/189.png?lm=1520611569',
#     'age': '24',
#     'height': '1,95',
#     'foot': 'links',
#     'internationalTeam': 'Norwegen',
#     'internationalTeamImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/125.png?lm=1520611569',
#     'internationalTeamStatus': 'Akt. Nationalspieler',
#     'internationalGames': '39',
#     'internationalGoals': '38',
#     'internationalTeamShortTag': 'A',
#     'internationalShirtNumber': '9',
#     'internationalWmMember': False,
#     'internationalValueRank': 1,
#     'country': 'Norwegen',
#     'countrynameEN': 'Norway',
#     'countryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/125.png?lm=1520611569',
#     'countryShortName': 'NOR',
#     'secondCountry': '',
#     'secondCountryImage': '',
#     'league': 'Premier League',
#     'leaguenameEN': 'Premier League',
#     'leagueLogo': 'https://tmssl.akamaized.net//images/logo/normal/gb1.png?lm=1521104656',
#     'clubImage': 'https://tmssl.akamaized.net//images/wappen/medium/281.png?lm=1467356331',
#     'club': 'Manchester City',
#     'clubnameEN': 'Manchester City',
#     'clubID': '281',
#     'loan': {'loan': '',
#      'loanStart': '',
#      'loanUntil': '',
#      'contractOptions': '',
#      'ownerName': '',
#      'ownerID': '',
#      'ownerImage': '',
#      'ownerContractUntil': ''},
#     'contractExpiryDate': '30.06.2034',
#     'agent': 'Rafaela Pimenta',
#     'agentId': '282',
#     'agentVerificationStatus': '1',
#     'agentVerificationDate': 1673305200,
#     'outfitter': '',
#     'positionGroup': 'Sturm',
#     'playerMainPosition': 'Mittelstürmer',
#     'playerSecondPosition': '',
#     'playerThirdPosition': '',
#     'marketValue': '200,00',
#     'marketValueCurrency': '€',
#     'marketValueNumeral': 'Mio.',
#     'marketValueLastChange': '16.12.2024',
#     'relatedness': [{'id': '107179',
#       'personName': 'A. Haaland',
#       'personGroup': 'spieler',
#       'personID': '117351',
#       'degreeOfRelationship': 'Sohn'},
#      {'id': '435587',
#       'personName': 'J. Brunes',
#       'personGroup': 'spieler',
#       'personID': '491830',
#       'degreeOfRelationship': 'Cousin'},
#      {'id': '748755',
#       'personName': 'Albert Tjåland',
#       'personGroup': 'spieler',
#       'personID': '844294',
#       'degreeOfRelationship': 'Cousin'}],
#     'injury': {'id': '', 'title': '', 'until': '-', 'rehabilitationFlag': ''},
#     'absence': {'id': '',
#      'title': '',
#      'until': '-',
#      'competitionID': '',
#      'matches': ''},
#     'allSuspensions': []},
#    'performanceSeasons': [{'key': '2024', 'title': '24/25'},
#     {'key': '2023', 'title': '23/24'},
#     {'key': '2022', 'title': '22/23'},
#     {'key': '2021', 'title': '21/22'},
#     {'key': '2020', 'title': '20/21'},
#     {'key': '2019', 'title': '19/20'},
#     {'key': '2018', 'title': '18/19'},
#     {'key': '2017', 'title': '17/18'},
#     {'key': '2016', 'title': '16/17'},
#     {'key': '2015', 'title': '15/16'}],
#    'heroImages': [{'id': '148917',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-2024-1727103341-148917.jpg?lm=1727103361',
#      'source': 'IMAGO'},
#     {'id': '157818',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-scores-for-manchester-city-2024-1736010622-157818.jpg?lm=1736010651',
#      'source': 'IMAGO'},
#     {'id': '148004',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-2024-1726331023-148004.jpg?lm=1726331039',
#      'source': 'IMAGO'},
#     {'id': '145419',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-2024-1724007958-145419.jpg?lm=1724007972',
#      'source': 'IMAGO'},
#     {'id': '145295',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-alf-inge-haaland-2023-1723796863-145295.jpg?lm=1723796899',
#      'source': 'IMAGO'},
#     {'id': '130532',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-1709072645-130532.jpg?lm=1709072661',
#      'source': 'IMAGO'},
#     {'id': '122571',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-2023-24-1700923761-122571.jpg?lm=1700923774',
#      'source': 'IMAGO'},
#     {'id': '68944',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-borussia-dortmund-2021-1628965181-68944.jpg?lm=1628965203',
#      'source': 'IMAGO'},
#     {'id': '120392',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-2023-1698268619-120392.jpg?lm=1698268631',
#      'source': 'IMAGO'},
#     {'id': '115706',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-2023-24-1693673100-115706.jpg?lm=1693673118',
#      'source': 'IMAGO'},
#     {'id': '113711',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/haaland-pots-2022-23-spotlight-1691591078-113711.jpg?lm=1691591084',
#      'source': 'TM/IMAGO'},
#     {'id': '106474',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-torrekord-premier-league-1683148042-106474.jpg?lm=1683148075',
#      'source': 'IMAGO'},
#     {'id': '105133',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-2023-1681027934-105133.jpg?lm=1681027963',
#      'source': 'IMAGO'},
#     {'id': '103618',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-and-pep-guardiola-1678830078-103618.jpg?lm=1678830089',
#      'source': 'IMAGO'},
#     {'id': '103617',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/funferpack-von-erling-haaland-in-der-champions-league-2022-23-1678829921-103617.jpg?lm=1678829939',
#      'source': 'IMAGO'},
#     {'id': '102040',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-2022-23-1676530632-102040.jpg?lm=1676530644',
#      'source': 'IMAGO'},
#     {'id': '100394',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-man-city-2023-1674201974-100394.jpg?lm=1674202000',
#      'source': 'IMAGO'},
#     {'id': '92551',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-man-city-2022-1663424977-92551.jpg?lm=1663424984',
#      'source': 'IMAGO'},
#     {'id': '92390',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-trifft-fur-man-city-gegen-den-bvb-2022-1663189387-92390.jpg?lm=1663189402',
#      'source': 'IMAGO'},
#     {'id': '91459',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-2022-1662016665-91459.jpg?lm=1662016686',
#      'source': 'IMAGO'},
#     {'id': '89750',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-bei-manchester-city-2022-1659945400-89750.jpg?lm=1659945431',
#      'source': 'IMAGO'},
#     {'id': '89727',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-2022-1659896276-89727.jpg?lm=1659896286',
#      'source': 'IMAGO'},
#     {'id': '88451',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-manchester-city-2022-1657811547-88451.jpg?lm=1657811563',
#      'source': 'IMAGO'},
#     {'id': '67010',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-dfb-pokal-sieg-2020-21-borussia-dortmund-bvb-1625911221-67010.jpg?lm=1625911265',
#      'source': 'IMAGO'},
#     {'id': '63003',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-borussia-dortmund-1621586564-63003.jpg?lm=1621586574',
#      'source': 'IMAGO'},
#     {'id': '61051',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/dortmund-sturmer-erling-haaland-im-sonder-trikot-1618818005-61051.jpg?lm=1618818019',
#      'source': 'IMAGO'},
#     {'id': '51999',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-borussia-dortmund-1606253819-51999.jpg?lm=1606253843',
#      'source': 'IMAGO'},
#     {'id': '51814',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-borussia-dortmund-1605992945-51814.jpg?lm=1605992972',
#      'source': 'IMAGO'},
#     {'id': '41355',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-1592064065-41355.jpg?lm=1592064077',
#      'source': 'IMAGO'},
#     {'id': '31574',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/haaland-im-trikot-vom-bvb-1581427183-31574.jpg?lm=1581427198',
#      'source': 'TM/IMAGO'},
#     {'id': '30029',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-borussia-dortmund-1579364356-30029.jpg?lm=1579364372',
#      'source': 'IMAGO'},
#     {'id': '31181',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-watzek-zorc-borussia-dortmund-bvb-1580898014-31181.jpg?lm=1580898056',
#      'source': 'IMAGO'},
#     {'id': '28198',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-red-bull-salzburg-1576056688-28198.jpg?lm=1576056702',
#      'source': 'IMAGO'},
#     {'id': '27072',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-rb-salzburg-1572537473-27072.jpg?lm=1572537487',
#      'source': 'IMAGO'},
#     {'id': '25859',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-braut-haland-salzburg-torjubel-1568803109-25859.jpg?lm=1568803125',
#      'source': 'IMAGO'},
#     {'id': '25346',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-braut-haland-red-bull-salzburg-1567521270-25346.jpg?lm=1567521420',
#      'source': 'IMAGO'},
#     {'id': '16393',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-braut-haland-molde-1530511521-16393.jpg?lm=1530511536',
#      'source': 'IMAGO'}]},
#   'status': True,
#   'message': 'Successful'},
#  '342229': {'data': {'share': {'title': 'Kylian Mbappé - Spielerprofil',
#     'url': 'https://www.transfermarkt.de/kylian-mbappe/profil/spieler/342229',
#     'description': 'Das ist das Spielerprofil von Kylian Mbappé.'},
#    'playerProfile': {'playerID': '342229',
#     'playerImage': 'https://img.a.transfermarkt.technology/portrait/medium/342229-1682683695.jpg?lm=1',
#     'playerName': 'Kylian Mbappé',
#     'playerFullName': 'Kylian Mbappé',
#     'birthplace': 'Paris',
#     'dateOfBirth': '20.12.1998',
#     'dateOfDeath': None,
#     'playerShirtNumber': '9',
#     'birthplaceCountry': 'Frankreich',
#     'birthplaceCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/50.png?lm=1520611569',
#     'age': '26',
#     'height': '1,78',
#     'foot': 'rechts',
#     'internationalTeam': 'Frankreich',
#     'internationalTeamImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/50.png?lm=1520611569',
#     'internationalTeamStatus': 'Nationalspieler',
#     'internationalGames': '86',
#     'internationalGoals': '48',
#     'internationalTeamShortTag': 'A',
#     'internationalShirtNumber': '10',
#     'internationalWmMember': False,
#     'internationalValueRank': 3,
#     'country': 'Frankreich',
#     'countrynameEN': 'France',
#     'countryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/50.png?lm=1520611569',
#     'countryShortName': 'FRA',
#     'secondCountry': 'Kamerun',
#     'secondCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/31.png?lm=1520611569',
#     'league': 'LaLiga',
#     'leaguenameEN': 'LaLiga',
#     'leagueLogo': 'https://tmssl.akamaized.net//images/logo/normal/es1.png?lm=1725974302',
#     'clubImage': 'https://tmssl.akamaized.net//images/wappen/medium/418.png?lm=1729684474',
#     'club': 'Real Madrid',
#     'clubnameEN': 'Real Madrid',
#     'clubID': '418',
#     'loan': {'loan': '',
#      'loanStart': '',
#      'loanUntil': '',
#      'contractOptions': '',
#      'ownerName': '',
#      'ownerID': '',
#      'ownerImage': '',
#      'ownerContractUntil': ''},
#     'contractExpiryDate': '30.06.2029',
#     'agent': 'Familienangehörige',
#     'agentId': '1207',
#     'agentVerificationStatus': None,
#     'agentVerificationDate': False,
#     'outfitter': '',
#     'positionGroup': 'Sturm',
#     'playerMainPosition': 'Mittelstürmer',
#     'playerSecondPosition': 'Linksaußen',
#     'playerThirdPosition': 'Rechtsaußen',
#     'marketValue': '160,00',
#     'marketValueCurrency': '€',
#     'marketValueNumeral': 'Mio.',
#     'marketValueLastChange': '27.12.2024',
#     'relatedness': [{'id': '40446',
#       'personName': 'J. Kembo Ekoko',
#       'personGroup': 'spieler',
#       'personID': '38062',
#       'degreeOfRelationship': 'Halbbruder'},
#      {'id': '903666',
#       'personName': 'Ethan Mbappé',
#       'personGroup': 'spieler',
#       'personID': '1018923',
#       'degreeOfRelationship': 'Bruder'},
#      {'id': '24749',
#       'personName': 'Pierre Mbappé',
#       'personGroup': 'trainer',
#       'personID': '258275',
#       'degreeOfRelationship': 'Neffe'}],
#     'injury': {'id': '', 'title': '', 'until': '-', 'rehabilitationFlag': ''},
#     'absence': {'id': '',
#      'title': '',
#      'until': '-',
#      'competitionID': '',
#      'matches': ''},
#     'allSuspensions': []},
#    'performanceSeasons': [{'key': '2024', 'title': '24/25'},
#     {'key': '2023', 'title': '23/24'},
#     {'key': '2022', 'title': '22/23'},
#     {'key': '2021', 'title': '21/22'},
#     {'key': '2020', 'title': '20/21'},
#     {'key': '2019', 'title': '19/20'},
#     {'key': '2018', 'title': '18/19'},
#     {'key': '2017', 'title': '17/18'},
#     {'key': '2016', 'title': '16/17'},
#     {'key': '2015', 'title': '15/16'},
#     {'key': '2014', 'title': '14/15'}],
#    'heroImages': [{'id': '161539',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-real-madrid-2025-1740002179-161539.jpg?lm=1740002206',
#      'source': 'IMAGO'},
#     {'id': '160954',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/erling-haaland-kylian-mbappe-manchester-city-real-madrid-2024-2025-1739352207-160954.jpg?lm=1739352260',
#      'source': 'IMAGO'},
#     {'id': '157092',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-real-madrid-2024-1734548996-157092.jpg?lm=1734549011',
#      'source': 'IMAGO'},
#     {'id': '155694',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/vini-mbappe-and-bellingham-real-madrid-2024-1733249934-155694.jpg?lm=1733249964',
#      'source': 'IMAGO'},
#     {'id': '145579',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-real-madrid-2024-2025-1724077177-145579.jpg?lm=1724077229',
#      'source': 'IMAGO'},
#     {'id': '145164',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-real-madrid-2024-1723667554-145164.jpg?lm=1723667567',
#      'source': 'IMAGO'},
#     {'id': '142555',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-real-madrid-2024-25-presentation-1721130438-142555.jpg?lm=1721130450',
#      'source': 'IMAGO'},
#     {'id': '139133',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mbappe-frankreich-2024-1042852118h-1718112402-139133.jpg?lm=1718112460',
#      'source': 'IMAGO'},
#     {'id': '138475',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-1717521239-138475.jpg?lm=1717521272',
#      'source': 'IMAGO'},
#     {'id': '136253',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-psg-2024-1715580268-136253.jpg?lm=1715580276',
#      'source': 'IMAGO'},
#     {'id': '131700',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mbappe-kylian-2023-2024-paris-sg-1710367904-131700.jpg?lm=1710367928',
#      'source': 'IMAGO'},
#     {'id': '116567',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-psg-23-24-1694609196-116567.jpg?lm=1694609207',
#      'source': 'IMAGO'},
#     {'id': '124683',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-ethan-mbappe-paris-saint-germain-2023-1703152022-124683.jpg?lm=1703152035',
#      'source': 'IMAGO'},
#     {'id': '112393',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mbappe-kylian-2022-2023-psg-1032346914hjpg-1690297101-112393.jpg?lm=1690297120',
#      'source': 'IMAGO'},
#     {'id': '102635',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-psg-2023-1677479173-102635.jpg?lm=1677479183',
#      'source': 'IMAGO'},
#     {'id': '92557',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-psg-2022-23-1663434399-92557.jpg?lm=1663434413',
#      'source': 'IMAGO'},
#     {'id': '89985',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/player-of-the-season-mbappe-spotlight-neu-1660218540-89985.jpg?lm=1660218543',
#      'source': 'TM/PSG'},
#     {'id': '85545',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-psg-2022-1653161100-85545.jpg?lm=1653161120',
#      'source': 'IMAGO'},
#     {'id': '83126',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-paris-saint-germain-2022-1649050213-83126.jpg?lm=1649050252',
#      'source': 'IMAGO'},
#     {'id': '64389',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-frankreich-mbappe-1623091843-64389.jpg?lm=1623091856',
#      'source': 'IMAGO'},
#     {'id': '58346',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-paris-saint-germain-1615274665-58346.jpg?lm=1615274684',
#      'source': 'IMAGO'},
#     {'id': '55175',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-paris-saint-germain-1611388326-55175.jpg?lm=1611388345',
#      'source': 'IMAGO'},
#     {'id': '48132',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-player-of-the-season-spotlight-1601475543-48132.jpg?lm=1601475546',
#      'source': 'Mbappé/Transfermarkt/imago'},
#     {'id': '30258',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-psg-1579705083-30258.jpg?lm=1579705099',
#      'source': 'IMAGO'},
#     {'id': '34755',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-solo-jubel-rasen-psg-paris-1585148898-34755.jpg?lm=1585148928',
#      'source': 'IMAGO'},
#     {'id': '33150',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-und-neymar-jubeln-beim-51-von-psg-in-lyon-1583387252-33150.jpg?lm=1583387267',
#      'source': 'IMAGO'},
#     {'id': '34742',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-jubel-psg-1585146429-34742.jpg?lm=1585146445',
#      'source': 'IMAGO'},
#     {'id': '34746',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mbappe-neymar-meisterschaft-paris-1585147416-34746.jpg?lm=1585147431',
#      'source': 'IMAGO'},
#     {'id': '30062',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mbappe-neymar-celebrate-1579519836-30062.jpg?lm=1579519860',
#      'source': 'IMAGO'},
#     {'id': '11861',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mbappe-kylian-paris-1504944620-11861.jpg?lm=1504944634',
#      'source': 'IMAGO'},
#     {'id': '17479',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-psg-1535876039-17479.jpg?lm=1535876079',
#      'source': 'IMAGO'},
#     {'id': '16618',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mbappe-1531726753-16618.jpg?lm=1531726780',
#      'source': 'IMAGO'},
#     {'id': '15823',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbapp-frankreich-1528378397-15823.jpg?lm=1528378406',
#      'source': 'IMAGO'},
#     {'id': '15818',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbapp-paris-saint-germain-1528374625-15818.jpg?lm=1528374637',
#      'source': 'IMAGO'},
#     {'id': '11897',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/neymar-mbappe-cavani-1505280877-11897.jpg?lm=1505280883',
#      'source': 'IMAGO'},
#     {'id': '11217',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mbappe-monaco-1500565166-11217.jpg?lm=1500565181',
#      'source': 'IMAGO'},
#     {'id': '9125',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mbappe-monaco-1490332328-9125.jpg?lm=1490332349',
#      'source': 'IMAGO'},
#     {'id': '9739',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbapp-1492022654-9739.jpg?lm=1492022667',
#      'source': 'IMAGO'},
#     {'id': '6693',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kylian-mbappe-1482167420-6693.jpg?lm=1483606232',
#      'source': 'IMAGO'}]},
#   'status': True,
#   'message': 'Successful'},
#  '401923': {'data': {'share': {'title': 'Victor Osimhen - Spielerprofil',
#     'url': 'https://www.transfermarkt.de/victor-osimhen/profil/spieler/401923',
#     'description': 'Das ist das Spielerprofil von Victor Osimhen.'},
#    'playerProfile': {'playerID': '401923',
#     'playerImage': 'https://img.a.transfermarkt.technology/portrait/medium/401923-1737730981.jpg?lm=1',
#     'playerName': 'Victor Osimhen',
#     'playerFullName': 'Victor Osimhen',
#     'birthplace': 'Lagos',
#     'dateOfBirth': '29.12.1998',
#     'dateOfDeath': None,
#     'playerShirtNumber': '45',
#     'birthplaceCountry': 'Nigeria',
#     'birthplaceCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/124.png?lm=1520611569',
#     'age': '26',
#     'height': '1,86',
#     'foot': 'rechts',
#     'internationalTeam': 'Nigeria',
#     'internationalTeamImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/124.png?lm=1520611569',
#     'internationalTeamStatus': 'Akt. Nationalspieler',
#     'internationalGames': '35',
#     'internationalGoals': '21',
#     'internationalTeamShortTag': 'A',
#     'internationalShirtNumber': '9',
#     'internationalWmMember': False,
#     'internationalValueRank': 16,
#     'country': 'Nigeria',
#     'countrynameEN': 'Nigeria',
#     'countryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/124.png?lm=1520611569',
#     'countryShortName': 'NGA',
#     'secondCountry': '',
#     'secondCountryImage': '',
#     'league': 'Süper Lig',
#     'leaguenameEN': 'Süper Lig',
#     'leagueLogo': 'https://tmssl.akamaized.net//images/logo/normal/tr1.png?lm=1723019495',
#     'clubImage': 'https://tmssl.akamaized.net//images/wappen/medium/141.png?lm=1406739071',
#     'club': 'Galatasaray',
#     'clubnameEN': 'Galatasaray',
#     'clubID': '141',
#     'loan': {'loan': 'ist',
#      'loanStart': '04.09.2024',
#      'loanUntil': '30.06.2025',
#      'contractOptions': '',
#      'ownerName': 'SSC Neapel',
#      'ownerID': '6195',
#      'ownerImage': 'https://tmssl.akamaized.net//images/wappen/medium/6195.png?lm=1720861078',
#      'ownerContractUntil': '30.06.2026'},
#     'contractExpiryDate': '30.06.2026',
#     'agent': 'Roberto Calenda',
#     'agentId': '745',
#     'agentVerificationStatus': '0',
#     'agentVerificationDate': -62169987208,
#     'outfitter': '',
#     'positionGroup': 'Sturm',
#     'playerMainPosition': 'Mittelstürmer',
#     'playerSecondPosition': '',
#     'playerThirdPosition': '',
#     'marketValue': '75,00',
#     'marketValueCurrency': '€',
#     'marketValueNumeral': 'Mio.',
#     'marketValueLastChange': '23.12.2024',
#     'relatedness': [],
#     'injury': {'id': '', 'title': '', 'until': '-', 'rehabilitationFlag': ''},
#     'absence': {'id': '',
#      'title': '',
#      'until': '-',
#      'competitionID': '',
#      'matches': ''},
#     'allSuspensions': []},
#    'performanceSeasons': [{'key': '2024', 'title': '24/25'},
#     {'key': '2023', 'title': '23/24'},
#     {'key': '2022', 'title': '22/23'},
#     {'key': '2021', 'title': '21/22'},
#     {'key': '2020', 'title': '20/21'},
#     {'key': '2019', 'title': '19/20'},
#     {'key': '2018', 'title': '18/19'},
#     {'key': '2017', 'title': '17/18'},
#     {'key': '2016', 'title': '16/17'},
#     {'key': '2015', 'title': '15/16'},
#     {'key': '2014', 'title': '14/15'}],
#    'heroImages': [{'id': '148167',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-galatasaray-1726489537-148167.jpg?lm=1726489549',
#      'source': 'Galatasaray'},
#     {'id': '151843',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-mauro-icardi-galatasaray-1729501438-151843.jpg?lm=1729501462',
#      'source': 'Galatasaray'},
#     {'id': '153950',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-galatasaray-2024-2025-1731404509-153950.jpg?lm=1731404525',
#      'source': 'Galatasaray SK'},
#     {'id': '151844',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-galatasaray-overhead-kick-1729501581-151844.jpg?lm=1729501607',
#      'source': 'Galatasaray'},
#     {'id': '149826',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-galatasaray-2024-2025-1727681737-149826.jpg?lm=1727681746',
#      'source': 'Galatasaray'},
#     {'id': '147269',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-galatasaray-2024-2325-1725527528-147269.jpeg?lm=1725527538',
#      'source': 'Galatasaray SK'},
#     {'id': '147268',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-galatasaray-2024-2325-1725527494-147268.jpeg?lm=1725527505',
#      'source': 'Galatasaray SK'},
#     {'id': '134033',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-napoli-2023-2324-1712838138-134033.jpg?lm=1712838156',
#      'source': 'IMAGO'},
#     {'id': '124162',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-and-kvicha-kvaratskhelia-napoli-2023-24-1702801166-124162.jpg?lm=1702801183',
#      'source': 'IMAGO'},
#     {'id': '121611',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-napoli-2023-2324-1699619340-121611.jpg?lm=1699619350',
#      'source': 'IMAGO'},
#     {'id': '116557',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-nigeria-2023-1694599297-116557.jpg?lm=1694599329',
#      'source': 'IMAGO'},
#     {'id': '117800',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-ssc-neapel-1695793340-117800.jpg?lm=1695793353',
#      'source': 'IMAGO'},
#     {'id': '114241',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-napoli-2023-2324-1692266331-114241.jpg?lm=1692266347',
#      'source': 'IMAGO'},
#     {'id': '94105',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-ssc-neapel-2022-1665600735-94105.jpg?lm=1665600744',
#      'source': 'IMAGO'},
#     {'id': '91341',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-napoli-2022-1661847649-91341.jpg?lm=1661847679',
#      'source': 'IMAGO'},
#     {'id': '82885',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-nigeria-2021-1648634119-82885.jpg?lm=1648634136',
#      'source': 'IMAGO'},
#     {'id': '81913',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-napoli-2021-22-1647250161-81913.jpg?lm=1647250172',
#      'source': 'IMAGO'},
#     {'id': '70754',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-napoli-1631176538-70754.jpg?lm=1631176565',
#      'source': 'IMAGO'},
#     {'id': '63187',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-ssc-napoli-1621608656-63187.jpg?lm=1621608689',
#      'source': 'IMAGO'},
#     {'id': '63186',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-ssc-napoli-1621608652-63186.jpg?lm=1621608683',
#      'source': 'IMAGO'},
#     {'id': '63185',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-ssc-napoli-1621608641-63185.jpg?lm=1621608667',
#      'source': 'IMAGO'},
#     {'id': '59831',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-napoli-20-21-1617205313-59831.jpg?lm=1617205326',
#      'source': 'IMAGO'},
#     {'id': '46609',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-ssc-napoli-1599057121-46609.jpg?lm=1599057096',
#      'source': 'IMAGO'},
#     {'id': '43502',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/osimhen-napoli-1594735301-43502.jpg?lm=1594735286',
#      'source': 'Transfermarkt'},
#     {'id': '39619',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-losc-lilla-1590497523-39619.jpg?lm=1590497523',
#      'source': 'IMAGO'},
#     {'id': '26334',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-losc-lille-1570443292-26334.jpg?lm=1570443539',
#      'source': 'IMAGO'},
#     {'id': '22477',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-rsc-charleroi-1558967272-22477.jpg?lm=1558967291',
#      'source': 'IMAGO'},
#     {'id': '18368',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-rsc-charleroi-1540236193-18368.jpg?lm=1540236215',
#      'source': 'IMAGO'},
#     {'id': '4936',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-1454510353-4936.jpg?lm=1483606014',
#      'source': 'IMAGO'},
#     {'id': '4789',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-1446113681-4789.jpg?lm=1483605995',
#      'source': 'IMAGO'},
#     {'id': '4788',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/victor-osimhen-1446044050-4788.jpg?lm=1483605995',
#      'source': 'IMAGO'}]},
#   'status': True,
#   'message': 'Successful'},
#  '146854': {'data': {'share': {'title': 'Wissam Ben Yedder - Spielerprofil',
#     'url': 'https://www.transfermarkt.de/wissam-ben-yedder/profil/spieler/146854',
#     'description': 'Das ist das Spielerprofil von Wissam Ben Yedder.'},
#    'playerProfile': {'playerID': '146854',
#     'playerImage': 'https://img.a.transfermarkt.technology/portrait/medium/146854-1614089939.jpg?lm=1',
#     'playerName': 'Wissam Ben Yedder',
#     'playerFullName': 'Wissam Ben Yedder',
#     'birthplace': 'Sarcelles',
#     'dateOfBirth': '12.08.1990',
#     'dateOfDeath': None,
#     'playerShirtNumber': '',
#     'birthplaceCountry': 'Frankreich',
#     'birthplaceCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/50.png?lm=1520611569',
#     'age': '34',
#     'height': '1,70',
#     'foot': 'beidfüßig',
#     'internationalTeam': 'Frankreich',
#     'internationalTeamImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/50.png?lm=1520611569',
#     'internationalTeamStatus': 'Ehem. Nationalspieler',
#     'internationalGames': '19',
#     'internationalGoals': '3',
#     'internationalTeamShortTag': 'A',
#     'internationalShirtNumber': '9',
#     'internationalWmMember': False,
#     'internationalValueRank': 430,
#     'country': 'Frankreich',
#     'countrynameEN': 'France',
#     'countryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/50.png?lm=1520611569',
#     'countryShortName': 'FRA',
#     'secondCountry': 'Tunesien',
#     'secondCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/173.png?lm=1520611569',
#     'league': '',
#     'leaguenameEN': '',
#     'leagueLogo': '',
#     'clubImage': 'https://tmssl.akamaized.net//images/wappen/medium/515.png?lm=1456997255',
#     'club': 'Vereinslos',
#     'clubnameEN': 'Without Club',
#     'clubID': '515',
#     'loan': {'loan': '',
#      'loanStart': '',
#      'loanUntil': '',
#      'contractOptions': '',
#      'ownerName': '',
#      'ownerID': '',
#      'ownerImage': '',
#      'ownerContractUntil': ''},
#     'contractExpiryDate': '-',
#     'agent': '',
#     'agentId': '',
#     'agentVerificationStatus': '',
#     'agentVerificationDate': False,
#     'outfitter': '',
#     'positionGroup': 'Sturm',
#     'playerMainPosition': 'Mittelstürmer',
#     'playerSecondPosition': 'Hängende Spitze',
#     'playerThirdPosition': '',
#     'marketValue': '4,00',
#     'marketValueCurrency': '€',
#     'marketValueNumeral': 'Mio.',
#     'marketValueLastChange': '16.10.2024',
#     'relatedness': [],
#     'injury': {'id': '', 'title': '', 'until': '-', 'rehabilitationFlag': ''},
#     'absence': {'id': '',
#      'title': '',
#      'until': '-',
#      'competitionID': '',
#      'matches': ''},
#     'allSuspensions': []},
#    'performanceSeasons': [{'key': '2023', 'title': '23/24'},
#     {'key': '2022', 'title': '22/23'},
#     {'key': '2021', 'title': '21/22'},
#     {'key': '2020', 'title': '20/21'},
#     {'key': '2019', 'title': '19/20'},
#     {'key': '2018', 'title': '18/19'},
#     {'key': '2017', 'title': '17/18'},
#     {'key': '2016', 'title': '16/17'},
#     {'key': '2015', 'title': '15/16'},
#     {'key': '2014', 'title': '14/15'},
#     {'key': '2013', 'title': '13/14'},
#     {'key': '2012', 'title': '12/13'},
#     {'key': '2011', 'title': '11/12'},
#     {'key': '2010', 'title': '10/11'}],
#    'heroImages': [{'id': '115387',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/wissam-ben-yedder-as-monaco-2023-24-1693405783-115387.jpg?lm=1693405802',
#      'source': 'IMAGO'},
#     {'id': '30509',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/wissam-ben-yedder-as-monaco-1580045935-30509.jpg?lm=1580045958',
#      'source': 'IMAGO'},
#     {'id': '22865',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/wissam-ben-yedder-fc-sevilla-1560180659-22865.jpg?lm=1560180689',
#      'source': 'IMAGO'},
#     {'id': '10491',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/wissam-ben-yedder-zeigefinger-1496138136-10491.jpg?lm=1496138170',
#      'source': 'IMAGO'},
#     {'id': '10490',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/wissam-ben-yedder-1496138120-10490.jpg?lm=1496138158',
#      'source': 'IMAGO'},
#     {'id': '10489',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/wissam-ben-yedder-1496138107-10489.jpg?lm=1496138150',
#      'source': 'IMAGO'},
#     {'id': '10488',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/wissam-ben-yedder-fc-toulouse-1496138062-10488.jpg?lm=1496138076',
#      'source': 'IMAGO'}]},
#   'status': True,
#   'message': 'Successful'},
#  '580195': {'data': {'share': {'title': 'Jamal Musiala - Spielerprofil',
#     'url': 'https://www.transfermarkt.de/jamal-musiala/profil/spieler/580195',
#     'description': 'Das ist das Spielerprofil von Jamal Musiala.'},
#    'playerProfile': {'playerID': '580195',
#     'playerImage': 'https://img.a.transfermarkt.technology/portrait/medium/580195-1711745441.jpg?lm=1',
#     'playerName': 'Jamal Musiala',
#     'playerFullName': 'Jamal Musiala',
#     'birthplace': 'Stuttgart',
#     'dateOfBirth': '26.02.2003',
#     'dateOfDeath': None,
#     'playerShirtNumber': '42',
#     'birthplaceCountry': 'Deutschland',
#     'birthplaceCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/40.png?lm=1520612525',
#     'age': '22',
#     'height': '1,84',
#     'foot': 'rechts',
#     'internationalTeam': 'Deutschland',
#     'internationalTeamImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/40.png?lm=1520612525',
#     'internationalTeamStatus': 'Akt. Nationalspieler',
#     'internationalGames': '38',
#     'internationalGoals': '7',
#     'internationalTeamShortTag': 'A',
#     'internationalShirtNumber': '10',
#     'internationalWmMember': True,
#     'internationalValueRank': 3,
#     'country': 'Deutschland',
#     'countrynameEN': 'Germany',
#     'countryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/40.png?lm=1520612525',
#     'countryShortName': 'DEU',
#     'secondCountry': 'England',
#     'secondCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/189.png?lm=1520611569',
#     'league': 'Bundesliga',
#     'leaguenameEN': 'Bundesliga',
#     'leagueLogo': 'https://tmssl.akamaized.net//images/logo/normal/l1.png?lm=1525905518',
#     'clubImage': 'https://tmssl.akamaized.net//images/wappen/medium/27.png?lm=1729503608',
#     'club': 'FC Bayern München',
#     'clubnameEN': 'Bayern Munich',
#     'clubID': '27',
#     'loan': {'loan': '',
#      'loanStart': '',
#      'loanUntil': '',
#      'contractOptions': '',
#      'ownerName': '',
#      'ownerID': '',
#      'ownerImage': '',
#      'ownerContractUntil': ''},
#     'contractExpiryDate': '30.06.2030',
#     'agent': '11WINS GmbH',
#     'agentId': '2773',
#     'agentVerificationStatus': '1',
#     'agentVerificationDate': 1652306400,
#     'outfitter': '',
#     'positionGroup': 'Mittelfeld',
#     'playerMainPosition': 'Offensives Mittelfeld',
#     'playerSecondPosition': 'Zentrales Mittelfeld',
#     'playerThirdPosition': 'Linksaußen',
#     'marketValue': '140,00',
#     'marketValueCurrency': '€',
#     'marketValueNumeral': 'Mio.',
#     'marketValueLastChange': '20.12.2024',
#     'relatedness': [],
#     'injury': {'id': '', 'title': '', 'until': '-', 'rehabilitationFlag': ''},
#     'absence': {'id': '',
#      'title': '',
#      'until': '-',
#      'competitionID': '',
#      'matches': ''},
#     'allSuspensions': []},
#    'performanceSeasons': [{'key': '2024', 'title': '24/25'},
#     {'key': '2023', 'title': '23/24'},
#     {'key': '2022', 'title': '22/23'},
#     {'key': '2021', 'title': '21/22'},
#     {'key': '2020', 'title': '20/21'},
#     {'key': '2019', 'title': '19/20'},
#     {'key': '2018', 'title': '18/19'},
#     {'key': '2017', 'title': '17/18'},
#     {'key': '2016', 'title': '16/17'}],
#    'heroImages': [{'id': '119603',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/musiala-jamal-2023-2024-bayern-munich-1035545430hjpg-1697537568-119603.jpg?lm=1697537584',
#      'source': 'IMAGO'},
#     {'id': '139135',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/jamal-musiala-deutschland-dfb-2024-1718112592-139135.jpg?lm=1718112604',
#      'source': 'IMAGO'},
#     {'id': '107953',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/jamal-musiala-fc-bayern-2023-tor-zur-meisterschaft-1685202199-107953.jpg?lm=1685202211',
#      'source': 'IMAGO'},
#     {'id': '97226',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/jamal-musiala-deutschland-wm-2022-1669212991-97226.jpg?lm=1669212998',
#      'source': 'IMAGO'},
#     {'id': '92857',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/jamal-musiala-fc-bayern-2022-23-1663674857-92857.jpg?lm=1663674865',
#      'source': 'IMAGO'},
#     {'id': '86505',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/jamal-musiala-bayern-munchen-2022-1654757257-86505.jpg?lm=1654757280',
#      'source': 'IMAGO'},
#     {'id': '72597',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/jamal-musiala-deutschland-2021-1634030589-72597.jpg?lm=1634030616',
#      'source': 'IMAGO'},
#     {'id': '48600',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/jamal-musiala-fc-bayern-munchen-1602066963-48600.jpg?lm=1602066995',
#      'source': 'IMAGO'},
#     {'id': '41357',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/jamal-musiala-fc-bayern-1592065016-41357.jpg?lm=1592064999',
#      'source': 'IMAGO'},
#     {'id': '41061',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/jamal-musiala-trifft-fur-den-fc-bayern-munchen-ii-in-der-3-liga-1591771453-41061.jpg?lm=1591771472',
#      'source': 'IMAGO'},
#     {'id': '38552',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mamin-sanyang-tsg-1899-hoffenheim-jamal-musiala-fc-bayern-munchen-1589449300-38552.jpg?lm=1589449329',
#      'source': 'IMAGO'}]},
#   'status': True,
#   'message': 'Successful'}}

# %%
def clean_players_info(players_dict):

    output_list = []

    for player_id, player_data in players_dict.items():
        player_profile = player_data.get('data', {}).get('playerProfile', {})

        if not player_profile:
            continue

        player_id = player_profile.get('playerID', '')
        player_name = player_profile.get('playerName', '')



        market_value = (
            str(player_profile.get('marketValue', ' ')) + " " +
            str(player_profile.get('marketValueCurrency', ' ')) + " " +
            str(player_profile.get('marketValueNumeral', ' '))
        )

        output_list.append({
            'player_id': player_id,
            'player_name': player_name,
            'market_value': market_value
        })

    return output_list

# %%
players_info_2022 = clean_players_info(getplayersinfo_2022)

# %%
players_info_2022
# Out:
# [{'player_id': '418560',
#   'player_name': 'Erling Haaland',
#   'market_value': '200,00 € Mio.'},
#  {'player_id': '342229',
#   'player_name': 'Kylian Mbappé',
#   'market_value': '160,00 € Mio.'},
#  {'player_id': '401923',
#   'player_name': 'Victor Osimhen',
#   'market_value': '75,00 € Mio.'},
#  {'player_id': '146854',
#   'player_name': 'Wissam Ben Yedder',
#   'market_value': '4,00 € Mio.'},
#  {'player_id': '580195',
#   'player_name': 'Jamal Musiala',
#   'market_value': '140,00 € Mio.'}]

# %%
df_players_info_2022 = pd.DataFrame(players_info_2022)

# %%
df_players_info_2022
# Out:
#   player_id        player_name   market_value
# 0    418560     Erling Haaland  200,00 € Mio.
# 1    342229      Kylian Mbappé  160,00 € Mio.
# 2    401923     Victor Osimhen   75,00 € Mio.
# 3    146854  Wissam Ben Yedder    4,00 € Mio.
# 4    580195      Jamal Musiala  140,00 € Mio.

# %% [markdown]
# ### Players Profile Info 2024

# %%
getplayersinfo(list_top5_2024_ids)

# %%
getplayersinfo_2024 = read_json_ALL("getplayersinfo_2024.json")

# %%
getplayersinfo_2024
# Out:
# {'132098': {'data': {'share': {'title': 'Harry Kane - Spielerprofil',
#     'url': 'https://www.transfermarkt.de/harry-kane/profil/spieler/132098',
#     'description': 'Das ist das Spielerprofil von Harry Kane.'},
#    'playerProfile': {'playerID': '132098',
#     'playerImage': 'https://img.a.transfermarkt.technology/portrait/medium/132098-1700211169.jpg?lm=1',
#     'playerName': 'Harry Kane',
#     'playerFullName': 'Harry Kane',
#     'birthplace': 'London',
#     'dateOfBirth': '28.07.1993',
#     'dateOfDeath': None,
#     'playerShirtNumber': '9',
#     'birthplaceCountry': 'England',
#     'birthplaceCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/189.png?lm=1520611569',
#     'age': '31',
#     'height': '1,88',
#     'foot': 'rechts',
#     'internationalTeam': 'England',
#     'internationalTeamImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/189.png?lm=1520611569',
#     'internationalTeamStatus': 'Akt. Nationalspieler',
#     'internationalGames': '103',
#     'internationalGoals': '69',
#     'internationalTeamShortTag': 'A',
#     'internationalShirtNumber': '9',
#     'internationalWmMember': True,
#     'internationalValueRank': 8,
#     'country': 'England',
#     'countrynameEN': 'England',
#     'countryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/189.png?lm=1520611569',
#     'countryShortName': 'ENG',
#     'secondCountry': '',
#     'secondCountryImage': '',
#     'league': 'Bundesliga',
#     'leaguenameEN': 'Bundesliga',
#     'leagueLogo': 'https://tmssl.akamaized.net//images/logo/normal/l1.png?lm=1525905518',
#     'clubImage': 'https://tmssl.akamaized.net//images/wappen/medium/27.png?lm=1729503608',
#     'club': 'FC Bayern München',
#     'clubnameEN': 'Bayern Munich',
#     'clubID': '27',
#     'loan': {'loan': '',
#      'loanStart': '',
#      'loanUntil': '',
#      'contractOptions': '',
#      'ownerName': '',
#      'ownerID': '',
#      'ownerImage': '',
#      'ownerContractUntil': ''},
#     'contractExpiryDate': '30.06.2027',
#     'agent': 'CK66 Limited',
#     'agentId': '6432',
#     'agentVerificationStatus': None,
#     'agentVerificationDate': False,
#     'outfitter': '',
#     'positionGroup': 'Sturm',
#     'playerMainPosition': 'Mittelstürmer',
#     'playerSecondPosition': '',
#     'playerThirdPosition': '',
#     'marketValue': '90,00',
#     'marketValueCurrency': '€',
#     'marketValueNumeral': 'Mio.',
#     'marketValueLastChange': '20.12.2024',
#     'relatedness': [],
#     'injury': {'id': '', 'title': '', 'until': '-', 'rehabilitationFlag': ''},
#     'absence': {'id': '',
#      'title': '',
#      'until': '-',
#      'competitionID': '',
#      'matches': ''},
#     'allSuspensions': []},
#    'performanceSeasons': [{'key': '2024', 'title': '24/25'},
#     {'key': '2023', 'title': '23/24'},
#     {'key': '2022', 'title': '22/23'},
#     {'key': '2021', 'title': '21/22'},
#     {'key': '2020', 'title': '20/21'},
#     {'key': '2019', 'title': '19/20'},
#     {'key': '2018', 'title': '18/19'},
#     {'key': '2017', 'title': '17/18'},
#     {'key': '2016', 'title': '16/17'},
#     {'key': '2015', 'title': '15/16'},
#     {'key': '2014', 'title': '14/15'},
#     {'key': '2013', 'title': '13/14'},
#     {'key': '2012', 'title': '12/13'},
#     {'key': '2011', 'title': '11/12'},
#     {'key': '2010', 'title': '10/11'},
#     {'key': '2009', 'title': '09/10'}],
#    'heroImages': [{'id': '161038',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-dayot-upamecano-fc-bayern-munchen-2025-1739396957-161038.jpg?lm=1739397399',
#      'source': 'IMAGO'},
#     {'id': '158339',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-fc-bayern-munchen-2024-1736622842-158339.jpg?lm=1736622860',
#      'source': 'IMAGO'},
#     {'id': '151779',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-fc-bayern-munchen-2024-1729361929-151779.jpg?lm=1729361954',
#      'source': 'IMAGO'},
#     {'id': '148552',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kane-harry-jubel-fc-bayern-champions-league-1050366360-1726751521-148552.jpeg?lm=1726751531',
#      'source': 'IMAGO'},
#     {'id': '139262',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-england-2024-1718185017-139262.jpg?lm=1718185029',
#      'source': 'IMAGO'},
#     {'id': '133839',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-serge-gnabry-fc-bayern-2024-1712697205-133839.jpg?lm=1712697220',
#      'source': 'IMAGO'},
#     {'id': '121651',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-fc-bayern-munchen-2023-1699718701-121651.jpg?lm=1699718716',
#      'source': 'IMAGO'},
#     {'id': '120073',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-fc-bayern-munchen-2023-24-1697911545-120073.jpg?lm=1697911588',
#      'source': 'IMAGO'},
#     {'id': '115034',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-bayern-2023-1693155948-115034.jpg?lm=1693155959',
#      'source': 'IMAGO'},
#     {'id': '114190',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-fc-bayern-munchen-2023-1692194022-114190.jpg?lm=1692194046',
#      'source': 'IMAGO'},
#     {'id': '105957',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-tottenham-hotspur-1682263518-105957.jpg?lm=1682263535',
#      'source': 'IMAGO'},
#     {'id': '97939',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-england-2022-1670012756-97939.jpg?lm=1670012773',
#      'source': 'IMAGO'},
#     {'id': '71978',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-erzielt-einen-hattrick-fur-tottenham-in-der-conference-league-1633066850-71978.jpg?lm=1633066866',
#      'source': 'IMAGO'},
#     {'id': '71480',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-tottenham-1632233802-71480.jpg?lm=1632233811',
#      'source': 'IMAGO'},
#     {'id': '63938',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-england-1622632189-63938.jpg?lm=1622632197',
#      'source': 'IMAGO'},
#     {'id': '64966',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-england-2021-1623589738-64966.jpg?lm=1623589752',
#      'source': 'IMAGO'},
#     {'id': '50815',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-tottenham-hotspur-150th-premier-league-goal-1604912732-50815.jpg?lm=1604912769',
#      'source': 'IMAGO'},
#     {'id': '34032',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/kane-2017-1584439545-34032.jpg?lm=1584439563',
#      'source': 'TM/IMAGO'},
#     {'id': '24102',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-tottenham-hotspur-1564573285-24102.jpg?lm=1564573298',
#      'source': 'IMAGO'},
#     {'id': '21086',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-tottenham-hotspur-1552570684-21086.jpg?lm=1552570706',
#      'source': 'IMAGO'},
#     {'id': '13864',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-tottenham-hotspur-1517807447-13864.jpg?lm=1517807472',
#      'source': 'IMAGO'},
#     {'id': '16178',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-england-weltmeisterschaft-2018-1529352862-16178.jpg?lm=1529352881',
#      'source': 'IMAGO'},
#     {'id': '16044',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-england-1528886064-16044.jpg?lm=1528886099',
#      'source': 'IMAGO'},
#     {'id': '15830',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-england-1528379709-15830.jpg?lm=1528379718',
#      'source': 'IMAGO'},
#     {'id': '5487',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-1464868110-5487.jpg?lm=1483606072',
#      'source': 'IMAGO'},
#     {'id': '5139',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-1458056535-5139.jpg?lm=1483606033',
#      'source': 'IMAGO'},
#     {'id': '3947',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-1418318947-3947.jpg?lm=1483605893',
#      'source': 'Getty Images'},
#     {'id': '3946',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-1418318889-3946.jpg?lm=1483605892',
#      'source': 'Getty Images'},
#     {'id': '3945',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/harry-kane-1418318848-3945.jpg?lm=1483605892',
#      'source': 'Getty Images'}]},
#   'status': True,
#   'message': 'Successful'},
#  '148455': {'data': {'share': {'title': 'Mohamed Salah - Spielerprofil',
#     'url': 'https://www.transfermarkt.de/mohamed-salah/profil/spieler/148455',
#     'description': 'Das ist das Spielerprofil von Mohamed Salah.'},
#    'playerProfile': {'playerID': '148455',
#     'playerImage': 'https://img.a.transfermarkt.technology/portrait/medium/148455-1727337594.jpg?lm=1',
#     'playerName': 'Mohamed Salah',
#     'playerFullName': 'Mohamed Salah Hamed Ghaly',
#     'birthplace': 'Nagrig, Basyoun',
#     'dateOfBirth': '15.06.1992',
#     'dateOfDeath': None,
#     'playerShirtNumber': '11',
#     'birthplaceCountry': 'Ägypten',
#     'birthplaceCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/2.png?lm=1520611569',
#     'age': '32',
#     'height': '1,75',
#     'foot': 'links',
#     'internationalTeam': 'Ägypten',
#     'internationalTeamImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/2.png?lm=1520611569',
#     'internationalTeamStatus': 'Nationalspieler',
#     'internationalGames': '101',
#     'internationalGoals': '58',
#     'internationalTeamShortTag': 'A',
#     'internationalShirtNumber': '10',
#     'internationalWmMember': False,
#     'internationalValueRank': 38,
#     'country': 'Ägypten',
#     'countrynameEN': 'Egypt',
#     'countryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/2.png?lm=1520611569',
#     'countryShortName': 'EGY',
#     'secondCountry': '',
#     'secondCountryImage': '',
#     'league': 'Premier League',
#     'leaguenameEN': 'Premier League',
#     'leagueLogo': 'https://tmssl.akamaized.net//images/logo/normal/gb1.png?lm=1521104656',
#     'clubImage': 'https://tmssl.akamaized.net//images/wappen/medium/31.png?lm=1727873452',
#     'club': 'FC Liverpool',
#     'clubnameEN': 'Liverpool FC',
#     'clubID': '31',
#     'loan': {'loan': '',
#      'loanStart': '',
#      'loanUntil': '',
#      'contractOptions': '',
#      'ownerName': '',
#      'ownerID': '',
#      'ownerImage': '',
#      'ownerContractUntil': ''},
#     'contractExpiryDate': '30.06.2025',
#     'agent': '',
#     'agentId': '',
#     'agentVerificationStatus': '',
#     'agentVerificationDate': False,
#     'outfitter': '',
#     'positionGroup': 'Sturm',
#     'playerMainPosition': 'Rechtsaußen',
#     'playerSecondPosition': 'Hängende Spitze',
#     'playerThirdPosition': 'Mittelstürmer',
#     'marketValue': '55,00',
#     'marketValueCurrency': '€',
#     'marketValueNumeral': 'Mio.',
#     'marketValueLastChange': '16.12.2024',
#     'relatedness': [],
#     'injury': {'id': '', 'title': '', 'until': '-', 'rehabilitationFlag': ''},
#     'absence': {'id': '',
#      'title': '',
#      'until': '-',
#      'competitionID': '',
#      'matches': ''},
#     'allSuspensions': []},
#    'performanceSeasons': [{'key': '2024', 'title': '24/25'},
#     {'key': '2023', 'title': '23/24'},
#     {'key': '2022', 'title': '22/23'},
#     {'key': '2021', 'title': '21/22'},
#     {'key': '2020', 'title': '20/21'},
#     {'key': '2019', 'title': '19/20'},
#     {'key': '2018', 'title': '18/19'},
#     {'key': '2017', 'title': '17/18'},
#     {'key': '2016', 'title': '16/17'},
#     {'key': '2015', 'title': '15/16'},
#     {'key': '2014', 'title': '14/15'},
#     {'key': '2013', 'title': '13/14'},
#     {'key': '2012', 'title': '12/13'},
#     {'key': '2011', 'title': '11/12'},
#     {'key': '2010', 'title': '10/11'},
#     {'key': '2009', 'title': '09/10'}],
#    'heroImages': [{'id': '157334',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-liverpool-2024-1734932974-157334.jpg?lm=1734933154',
#      'source': 'IMAGO'},
#     {'id': '147758',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/salah-liverpool-2024-2025-1726059582-147758.jpg?lm=1726059622',
#      'source': 'IMAGO'},
#     {'id': '103123',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-fc-liverpool-1678041080-103123.jpg?lm=1678041091',
#      'source': 'IMAGO'},
#     {'id': '103122',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-liverpool-2022-23-1678041051-103122.jpg?lm=1678041072',
#      'source': 'IMAGO'},
#     {'id': '102378',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/liverpool-forward-mohamed-salah-1677012715-102378.jpg?lm=1677012734',
#      'source': 'IMAGO'},
#     {'id': '73462',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-fc-liverpool-2021-22-1635096181-73462.jpg?lm=1635096193',
#      'source': 'IMAGO'},
#     {'id': '73267',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-fc-liverpool-2021-1634742774-73267.jpg?lm=1634742783',
#      'source': 'IMAGO'},
#     {'id': '71713',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-liverpool-2021-1632687357-71713.jpg?lm=1632687374',
#      'source': 'IMAGO'},
#     {'id': '43006',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohames-salah-feiert-mit-mane-firmino-und-oxlade-chamberlain-seinen-treffer-fur-liverpool-1594272127-43006.jpg?lm=1594272099',
#      'source': 'IMAGO'},
#     {'id': '38557',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mo-salah-1589451469-38557.jpg?lm=1589451545',
#      'source': 'IMAGO'},
#     {'id': '20186',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-fc-liverpool-1548767052-20186.jpg?lm=1548767079',
#      'source': 'IMAGO'},
#     {'id': '20219',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-1548774718-20219.jpg?lm=1548774738',
#      'source': 'IMAGO'},
#     {'id': '14513',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/salah-mohamed-liverpool-1521366000-14513.jpg?lm=1521366010',
#      'source': 'IMAGO'},
#     {'id': '20146',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mane-salah-firmino-1548686833-20146.jpg?lm=1548687049',
#      'source': 'IMAGO'},
#     {'id': '12878',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-1511547380-12878.jpg?lm=1511547395',
#      'source': 'IMAGO'},
#     {'id': '11632',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohammed-salah-liverpool-1503568115-11632.jpg?lm=1503568125',
#      'source': 'IMAGO'},
#     {'id': '10873',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/salah-1498163349-10873.jpg?lm=1498163362',
#      'source': 'IMAGO'},
#     {'id': '6593',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-1480421830-6593.jpg?lm=1483606220',
#      'source': 'IMAGO'},
#     {'id': '5243',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-1461669843-5243.jpg?lm=1483606044',
#      'source': 'IMAGO'},
#     {'id': '5242',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-1461669823-5242.jpg?lm=1483606043',
#      'source': 'IMAGO'},
#     {'id': '5241',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-1461669801-5241.jpg?lm=1483606043',
#      'source': 'IMAGO'},
#     {'id': '15119',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/mohamed-salah-fc-basel-im-duell-mit-marcell-jansen-hsv-1524821485-15119.jpg?lm=1524821500',
#      'source': 'IMAGO'}]},
#   'status': True,
#   'message': 'Successful'},
#  '349066': {'data': {'share': {'title': 'Alexander Isak - Spielerprofil',
#     'url': 'https://www.transfermarkt.de/alexander-isak/profil/spieler/349066',
#     'description': 'Das ist das Spielerprofil von Alexander Isak.'},
#    'playerProfile': {'playerID': '349066',
#     'playerImage': 'https://img.a.transfermarkt.technology/portrait/medium/349066-1680791339.jpg?lm=1',
#     'playerName': 'Alexander Isak',
#     'playerFullName': 'Alexander Isak',
#     'birthplace': 'Solna',
#     'dateOfBirth': '21.09.1999',
#     'dateOfDeath': None,
#     'playerShirtNumber': '14',
#     'birthplaceCountry': 'Schweden',
#     'birthplaceCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/147.png?lm=1520611569',
#     'age': '25',
#     'height': '1,92',
#     'foot': 'rechts',
#     'internationalTeam': 'Schweden',
#     'internationalTeamImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/147.png?lm=1520611569',
#     'internationalTeamStatus': 'Akt. Nationalspieler',
#     'internationalGames': '50',
#     'internationalGoals': '15',
#     'internationalTeamShortTag': 'A',
#     'internationalShirtNumber': '9',
#     'internationalWmMember': False,
#     'internationalValueRank': 16,
#     'country': 'Schweden',
#     'countrynameEN': 'Sweden',
#     'countryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/147.png?lm=1520611569',
#     'countryShortName': 'SWE',
#     'secondCountry': 'Eritrea',
#     'secondCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/46.png?lm=1520611569',
#     'league': 'Premier League',
#     'leaguenameEN': 'Premier League',
#     'leagueLogo': 'https://tmssl.akamaized.net//images/logo/normal/gb1.png?lm=1521104656',
#     'clubImage': 'https://tmssl.akamaized.net//images/wappen/medium/762.png?lm=1472921161',
#     'club': 'Newcastle United',
#     'clubnameEN': 'Newcastle United',
#     'clubID': '762',
#     'loan': {'loan': '',
#      'loanStart': '',
#      'loanUntil': '',
#      'contractOptions': '',
#      'ownerName': '',
#      'ownerID': '',
#      'ownerImage': '',
#      'ownerContractUntil': ''},
#     'contractExpiryDate': '30.06.2028',
#     'agent': 'Universal Twenty Two',
#     'agentId': '2722',
#     'agentVerificationStatus': '1',
#     'agentVerificationDate': 1672268400,
#     'outfitter': '',
#     'positionGroup': 'Sturm',
#     'playerMainPosition': 'Mittelstürmer',
#     'playerSecondPosition': '',
#     'playerThirdPosition': '',
#     'marketValue': '75,00',
#     'marketValueCurrency': '€',
#     'marketValueNumeral': 'Mio.',
#     'marketValueLastChange': '16.12.2024',
#     'relatedness': [],
#     'injury': {'id': '', 'title': '', 'until': '-', 'rehabilitationFlag': ''},
#     'absence': {'id': '',
#      'title': '',
#      'until': '-',
#      'competitionID': '',
#      'matches': ''},
#     'allSuspensions': []},
#    'performanceSeasons': [{'key': '2024', 'title': '24/25'},
#     {'key': '2023', 'title': '23/24'},
#     {'key': '2022', 'title': '22/23'},
#     {'key': '2021', 'title': '21/22'},
#     {'key': '2020', 'title': '20/21'},
#     {'key': '2019', 'title': '19/20'},
#     {'key': '2018', 'title': '18/19'},
#     {'key': '2017', 'title': '17/18'},
#     {'key': '2016', 'title': '16/17'},
#     {'key': '2015', 'title': '15/16'},
#     {'key': '2014', 'title': '14/15'},
#     {'key': '2013', 'title': '13/14'}],
#    'heroImages': [{'id': '157462',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-newcastle-2024-1054261762-1735296605-157462.jpg?lm=1735296616',
#      'source': 'IMAGO'},
#     {'id': '105954',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-kieran-trippier-newcastle-united-1682261192-105954.jpg?lm=1682261212',
#      'source': 'IMAGO'},
#     {'id': '92414',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-newcastle-united-2022-1663233750-92414.jpg?lm=1663233761',
#      'source': 'IMAGO'},
#     {'id': '90920',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-real-sociedad-san-sebastian-2022-1661346249-90920.jpg?lm=1661346270',
#      'source': 'IMAGO'},
#     {'id': '82886',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-schweden-2021-1648634341-82886.jpg?lm=1648634352',
#      'source': 'IMAGO'},
#     {'id': '57146',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-real-sociedad-1613995240-57146.jpg?lm=1613995277',
#      'source': 'IMAGO'},
#     {'id': '32242',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-real-sociedad-san-sebastian-1582539391-32242.jpg?lm=1582539412',
#      'source': 'IMAGO'},
#     {'id': '31461',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-real-sociedad-san-sebastian-1581314347-31461.jpg?lm=1581314368',
#      'source': 'IMAGO'},
#     {'id': '31343',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-real-sociedad-san-sebastian-1581018148-31343.jpg?lm=1581018155',
#      'source': 'IMAGO'},
#     {'id': '28372',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-real-sociedad-1576405251-28372.jpg?lm=1576405300',
#      'source': 'IMAGO'},
#     {'id': '21526',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/bvb-leihgabe-alexander-isak-im-trikot-von-willem-ii-1554374591-21526.jpg?lm=1554374605',
#      'source': 'IMAGO'},
#     {'id': '17739',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-bvb-1537204978-17739.jpg?lm=1537205027',
#      'source': 'IMAGO'},
#     {'id': '15374',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-bvb-1526220029-15374.jpg?lm=1526220043',
#      'source': 'IMAGO'},
#     {'id': '12442',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-bvb-1508922816-12442.jpg?lm=1508922828',
#      'source': 'IMAGO'},
#     {'id': '12441',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-schweden-1508922696-12441.jpg?lm=1508922705',
#      'source': 'IMAGO'},
#     {'id': '6176',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/alexander-isak-1475155766-6176.jpg?lm=1483606157',
#      'source': 'IMAGO'}]},
#   'status': True,
#   'message': 'Successful'},
#  '38253': {'data': {'share': {'title': 'Robert Lewandowski - Spielerprofil',
#     'url': 'https://www.transfermarkt.de/robert-lewandowski/profil/spieler/38253',
#     'description': 'Das ist das Spielerprofil von Robert Lewandowski.'},
#    'playerProfile': {'playerID': '38253',
#     'playerImage': 'https://img.a.transfermarkt.technology/portrait/medium/38253-1701118759.jpg?lm=1',
#     'playerName': 'Robert Lewandowski',
#     'playerFullName': 'Robert Lewandowski',
#     'birthplace': 'Warszawa',
#     'dateOfBirth': '21.08.1988',
#     'dateOfDeath': None,
#     'playerShirtNumber': '9',
#     'birthplaceCountry': 'Polen',
#     'birthplaceCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/135.png?lm=1520611569',
#     'age': '36',
#     'height': '1,85',
#     'foot': 'rechts',
#     'internationalTeam': 'Polen',
#     'internationalTeamImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/135.png?lm=1520611569',
#     'internationalTeamStatus': 'Nationalspieler',
#     'internationalGames': '156',
#     'internationalGoals': '84',
#     'internationalTeamShortTag': 'A',
#     'internationalShirtNumber': '9',
#     'internationalWmMember': False,
#     'internationalValueRank': 225,
#     'country': 'Polen',
#     'countrynameEN': 'Poland',
#     'countryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/135.png?lm=1520611569',
#     'countryShortName': 'POL',
#     'secondCountry': '',
#     'secondCountryImage': '',
#     'league': 'LaLiga',
#     'leaguenameEN': 'LaLiga',
#     'leagueLogo': 'https://tmssl.akamaized.net//images/logo/normal/es1.png?lm=1725974302',
#     'clubImage': 'https://tmssl.akamaized.net//images/wappen/medium/131.png?lm=1406739548',
#     'club': 'FC Barcelona',
#     'clubnameEN': 'FC Barcelona',
#     'clubID': '131',
#     'loan': {'loan': '',
#      'loanStart': '',
#      'loanUntil': '',
#      'contractOptions': '',
#      'ownerName': '',
#      'ownerID': '',
#      'ownerImage': '',
#      'ownerContractUntil': ''},
#     'contractExpiryDate': '30.06.2026',
#     'agent': 'Gol International',
#     'agentId': '220',
#     'agentVerificationStatus': '1',
#     'agentVerificationDate': 1659391200,
#     'outfitter': '',
#     'positionGroup': 'Sturm',
#     'playerMainPosition': 'Mittelstürmer',
#     'playerSecondPosition': '',
#     'playerThirdPosition': '',
#     'marketValue': '15,00',
#     'marketValueCurrency': '€',
#     'marketValueNumeral': 'Mio.',
#     'marketValueLastChange': '27.12.2024',
#     'relatedness': [],
#     'injury': {'id': '', 'title': '', 'until': '-', 'rehabilitationFlag': ''},
#     'absence': {'id': '',
#      'title': '',
#      'until': '-',
#      'competitionID': '',
#      'matches': ''},
#     'allSuspensions': []},
#    'performanceSeasons': [{'key': '2024', 'title': '24/25'},
#     {'key': '2023', 'title': '23/24'},
#     {'key': '2022', 'title': '22/23'},
#     {'key': '2021', 'title': '21/22'},
#     {'key': '2020', 'title': '20/21'},
#     {'key': '2019', 'title': '19/20'},
#     {'key': '2018', 'title': '18/19'},
#     {'key': '2017', 'title': '17/18'},
#     {'key': '2016', 'title': '16/17'},
#     {'key': '2015', 'title': '15/16'},
#     {'key': '2014', 'title': '14/15'},
#     {'key': '2013', 'title': '13/14'},
#     {'key': '2012', 'title': '12/13'},
#     {'key': '2011', 'title': '11/12'},
#     {'key': '2010', 'title': '10/11'},
#     {'key': '2009', 'title': '09/10'},
#     {'key': '2008', 'title': '08/09'},
#     {'key': '2007', 'title': '07/08'}],
#    'heroImages': [{'id': '155191',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-barcelona-2024-1732688506-155191.jpg?lm=1732688519',
#      'source': 'IMAGO'},
#     {'id': '152589',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-barcelona-2024-25-1730103967-152589.jpg?lm=1730103982',
#      'source': 'IMAGO'},
#     {'id': '148433',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-barcelona-2024-2025-1048846760h-1726670456-148433.jpg?lm=1726670470',
#      'source': 'IMAGO'},
#     {'id': '139140',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-poland-2024-1718113346-139140.jpg?lm=1718113360',
#      'source': 'IMAGO'},
#     {'id': '116570',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/ilkay-gundogan-marc-andre-ter-stegen-robert-lewandowski-fc-barcelona-2023-1694611061-116570.jpg?lm=1694611127',
#      'source': 'IMAGO'},
#     {'id': '135411',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-barcelona-1714426114-135411.jpg?lm=1714426181',
#      'source': 'IMAGO'},
#     {'id': '130023',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-cl-2023-24-1708554319-130023.jpg?lm=1708554337',
#      'source': 'IMAGO'},
#     {'id': '116054',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-barcelona-2023-2024-1693997875-116054.jpg?lm=1693997902',
#      'source': 'IMAGO'},
#     {'id': '95220',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-barcelona-2022-1667122253-95220.jpg?lm=1667122274',
#      'source': 'IMAGO'},
#     {'id': '91198',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-barcelona-2022-23-1661747767-91198.jpg?lm=1661747775',
#      'source': 'IMAGO'},
#     {'id': '89205',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-barcelona-2022-23-1658999953-89205.jpg?lm=1658999962',
#      'source': 'IMAGO'},
#     {'id': '100704',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-bayern-munchen-5-tore-gegen-wolfsburg-1674664036-100704.jpg?lm=1674664055',
#      'source': 'IMAGO'},
#     {'id': '88659',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-beim-fc-bayern-munchen-2022-1658229110-88659.jpg?lm=1658229124',
#      'source': 'IMAGO'},
#     {'id': '81651',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-bayern-munchen-2022-1646775926-81651.jpg?lm=1646775939',
#      'source': 'IMAGO'},
#     {'id': '80552',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-beim-fc-bayern-2022-1645374961-80552.jpg?lm=1645374981',
#      'source': 'IMAGO'},
#     {'id': '73017',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-bayern-munchen-2021-1634480783-73017.jpg?lm=1634480792',
#      'source': 'IMAGO'},
#     {'id': '69321',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/lewandowski-spieler-der-saison-2020-21-spotlight-1629456015-69321.jpg?lm=1629456018',
#      'source': 'FC Bayern/Transfermarkt'},
#     {'id': '69147',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-bayern-supercup-2021-1629231322-69147.jpg?lm=1629231334',
#      'source': 'IMAGO'},
#     {'id': '66219',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-polen-1624910845-66219.jpg?lm=1624910858',
#      'source': 'IMAGO'},
#     {'id': '62991',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/bayern-sturmer-robert-lewandowski-1621585713-62991.jpg?lm=1621585726',
#      'source': 'IMAGO'},
#     {'id': '62195',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-bayern-munchen-1620497504-62195.jpg?lm=1620497532',
#      'source': 'IMAGO'},
#     {'id': '59203',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-bayern-munchen-2020-2021-1616256371-59203.jpg?lm=1616256381',
#      'source': 'IMAGO'},
#     {'id': '56221',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-1612816068-56221.jpg?lm=1612816083',
#      'source': 'IMAGO'},
#     {'id': '48719',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/player-of-the-season-robert-lewandowski-spotlight-1602156334-48719.jpg?lm=1602156344',
#      'source': 'Transfermarkt/FC Bayern München/imago'},
#     {'id': '17122',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-bayern-torjubel-1534105102-17122.jpg?lm=1534105129',
#      'source': 'IMAGO'},
#     {'id': '33241',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-im-trikot-des-fc-bayern-munchen-1583495297-33241.jpg?lm=1583495310',
#      'source': 'IMAGO'},
#     {'id': '986',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-1404400213-986.jpg?lm=1483605538',
#      'source': 'Getty Images'},
#     {'id': '15836',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-polen-1528381175-15836.jpg?lm=1528381186',
#      'source': 'IMAGO'},
#     {'id': '20788',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-bayern-munchen-1551554335-20788.jpg?lm=1551554365',
#      'source': 'IMAGO'},
#     {'id': '36149',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-lech-posen-1586352022-36149.jpg?lm=1586352031',
#      'source': 'IMAGO'},
#     {'id': '17351',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-fc-bayern-mnchen-2018-19-1535143829-17351.jpg?lm=1535143852',
#      'source': 'IMAGO'},
#     {'id': '11863',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/lewandowski-robert-bayern-1504950993-11863.jpg?lm=1504951020',
#      'source': 'IMAGO'},
#     {'id': '14712',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-1522521074-14712.jpg?lm=1522521092',
#      'source': 'IMAGO'},
#     {'id': '11969',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/lewandowski-1505637227-11969.jpg?lm=1505637238',
#      'source': 'IMAGO'},
#     {'id': '989',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-1404400325-989.jpg?lm=1483605539',
#      'source': 'Getty Images'},
#     {'id': '9989',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/bayern-jubel-lewandowski-1493541017-9989.jpg?lm=1493541038',
#      'source': 'IMAGO'},
#     {'id': '6145',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-1474452789-6145.jpg?lm=1483606151',
#      'source': 'IMAGO'},
#     {'id': '6146',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-1474452843-6146.jpg?lm=1483606151',
#      'source': 'IMAGO'},
#     {'id': '1187',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-1404908878-1187.jpg?lm=1483605566',
#      'source': 'Getty Images'},
#     {'id': '988',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-1404400290-988.jpg?lm=1483605539',
#      'source': 'Getty Images'},
#     {'id': '987',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-1404400247-987.jpg?lm=1483605539',
#      'source': 'Getty Images'},
#     {'id': '985',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/robert-lewandowski-1404400175-985.jpg?lm=1483605538',
#      'source': 'Getty Images'}]},
#   'status': True,
#   'message': 'Successful'},
#  '598577': {'data': {'share': {'title': 'Florian Wirtz - Spielerprofil',
#     'url': 'https://www.transfermarkt.de/florian-wirtz/profil/spieler/598577',
#     'description': 'Das ist das Spielerprofil von Florian Wirtz.'},
#    'playerProfile': {'playerID': '598577',
#     'playerImage': 'https://img.a.transfermarkt.technology/portrait/medium/598577-1689710503.jpg?lm=1',
#     'playerName': 'Florian Wirtz',
#     'playerFullName': 'Florian Wirtz',
#     'birthplace': 'Pulheim',
#     'dateOfBirth': '03.05.2003',
#     'dateOfDeath': None,
#     'playerShirtNumber': '10',
#     'birthplaceCountry': 'Deutschland',
#     'birthplaceCountryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/40.png?lm=1520612525',
#     'age': '21',
#     'height': '1,77',
#     'foot': 'rechts',
#     'internationalTeam': 'Deutschland',
#     'internationalTeamImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/40.png?lm=1520612525',
#     'internationalTeamStatus': 'Akt. Nationalspieler',
#     'internationalGames': '29',
#     'internationalGoals': '6',
#     'internationalTeamShortTag': 'A',
#     'internationalShirtNumber': '17',
#     'internationalWmMember': True,
#     'internationalValueRank': 3,
#     'country': 'Deutschland',
#     'countrynameEN': 'Germany',
#     'countryImage': 'https://tmssl.akamaized.net//images/flagge/verysmall/40.png?lm=1520612525',
#     'countryShortName': 'DEU',
#     'secondCountry': '',
#     'secondCountryImage': '',
#     'league': 'Bundesliga',
#     'leaguenameEN': 'Bundesliga',
#     'leagueLogo': 'https://tmssl.akamaized.net//images/logo/normal/l1.png?lm=1525905518',
#     'clubImage': 'https://tmssl.akamaized.net//images/wappen/medium/15.png?lm=1710156317',
#     'club': 'Bayer 04 Leverkusen',
#     'clubnameEN': 'Bayer 04 Leverkusen',
#     'clubID': '15',
#     'loan': {'loan': '',
#      'loanStart': '',
#      'loanUntil': '',
#      'contractOptions': '',
#      'ownerName': '',
#      'ownerID': '',
#      'ownerImage': '',
#      'ownerContractUntil': ''},
#     'contractExpiryDate': '30.06.2027',
#     'agent': 'Familienangehörige',
#     'agentId': '1207',
#     'agentVerificationStatus': None,
#     'agentVerificationDate': False,
#     'outfitter': '',
#     'positionGroup': 'Mittelfeld',
#     'playerMainPosition': 'Offensives Mittelfeld',
#     'playerSecondPosition': 'Rechtsaußen',
#     'playerThirdPosition': 'Linksaußen',
#     'marketValue': '140,00',
#     'marketValueCurrency': '€',
#     'marketValueNumeral': 'Mio.',
#     'marketValueLastChange': '20.12.2024',
#     'relatedness': [],
#     'injury': {'id': '', 'title': '', 'until': '-', 'rehabilitationFlag': ''},
#     'absence': {'id': '1',
#      'title': 'Gelbsperre',
#      'until': '23.03.2025',
#      'competitionID': 'UNFI',
#      'matches': '1'},
#     'allSuspensions': [{'id': '1',
#       'title': 'Gelbsperre',
#       'until': '23.03.2025',
#       'competitionID': 'UNFI',
#       'matches': '1'}]},
#    'performanceSeasons': [{'key': '2024', 'title': '24/25'},
#     {'key': '2023', 'title': '23/24'},
#     {'key': '2022', 'title': '22/23'},
#     {'key': '2021', 'title': '21/22'},
#     {'key': '2020', 'title': '20/21'},
#     {'key': '2019', 'title': '19/20'},
#     {'key': '2018', 'title': '18/19'},
#     {'key': '2017', 'title': '17/18'}],
#    'heroImages': [{'id': '158907',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/florian-wirtz-bayer-leverkusen-2024-1737227570-158907.jpg?lm=1737227591',
#      'source': 'IMAGO'},
#     {'id': '145307',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/florian-wirtz-leverkusen-2024-2025-1723800337-145307.jpg?lm=1723800356',
#      'source': 'IMAGO'},
#     {'id': '132929',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/florian-wirtz-deutschland-germany-dfb-team-2023-24-1711549208-132929.jpg?lm=1711549221',
#      'source': 'IMAGO'},
#     {'id': '134320',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/florian-wirtz-1713196678-134320.jpg?lm=1713196699',
#      'source': 'IMAGO'},
#     {'id': '119388',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/florian-wirtz-bayer-leverkusen-2023-1697372169-119388.jpg?lm=1697372187',
#      'source': 'IMAGO'},
#     {'id': '95158',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/florian-wirtz-bayer-leverkusen-2022-1666966918-95158.jpg?lm=1666966936',
#      'source': 'IMAGO'},
#     {'id': '94925',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/florian-wirtz-bayer-leverkusen-2022-1666762528-94925.jpg?lm=1666762537',
#      'source': 'IMAGO'},
#     {'id': '71224',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/florian-wirtz-trifft-fur-bayer-leverkusen-in-der-europa-league-1631817327-71224.jpg?lm=1631817339',
#      'source': 'IMAGO'},
#     {'id': '53761',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/florian-wirtz-bayer-04-1609326815-53761.jpg?lm=1609326846',
#      'source': 'IMAGO'},
#     {'id': '45807',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/florian-wirtz-bayer-leverkusen-1598013052-45807.jpg?lm=1598013037',
#      'source': 'IMAGO'},
#     {'id': '39034',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/florian-wirtz-bayer-leverkusen-1589869806-39034.jpg?lm=1589869813',
#      'source': 'IMAGO'},
#     {'id': '30560',
#      'url': 'https://tmssl.akamaized.net//images/foto/normal/florian-wirtz-1-fc-koln-u17-1580134382-30560.jpg?lm=1580134395',
#      'source': 'IMAGO'}]},
#   'status': True,
#   'message': 'Successful'}}

# %%
players_info_2024 = clean_players_info(getplayersinfo_2024)

# %%
players_info_2024
# Out:
# [{'player_id': '132098',
#   'player_name': 'Harry Kane',
#   'market_value': '90,00 € Mio.'},
#  {'player_id': '148455',
#   'player_name': 'Mohamed Salah',
#   'market_value': '55,00 € Mio.'},
#  {'player_id': '349066',
#   'player_name': 'Alexander Isak',
#   'market_value': '75,00 € Mio.'},
#  {'player_id': '38253',
#   'player_name': 'Robert Lewandowski',
#   'market_value': '15,00 € Mio.'},
#  {'player_id': '598577',
#   'player_name': 'Florian Wirtz',
#   'market_value': '140,00 € Mio.'}]

# %%
df_players_info_2024 = pd.DataFrame(players_info_2024)

# %%
df_players_info_2024
# Out:
#    player_id         player_name   market_value
# 0     132098          Harry Kane   90,00 € Mio.
# 1     148455       Mohamed Salah   55,00 € Mio.
# 2     349066      Alexander Isak   75,00 € Mio.
# 3      38253  Robert Lewandowski   15,00 € Mio.
# 4     598577       Florian Wirtz  140,00 € Mio.

# %% [markdown]
# ### Merge 2024 Top 5 Players Info & Perfomance DataFrames

# %%
df_top5_2024['player_id'] = df_top5_2024['player_id'].astype(int)
df_players_info_2024['player_id'] = df_players_info_2024['player_id'].astype(int)

# %%
df_top5_2024 = pd.merge(df_top5_2024,df_players_info_2024, on = 'player_id', how = 'left')

# %%
df_top5_2024.drop(columns = ['player_id'], inplace = True)

# %%
df_top5_2024
# Out:
#    goals  assists  minutes_played  minutes_per_g_a         player_name  \
# 0     21        8            1648            56.83          Harry Kane
# 1     25       16            2395            58.41       Mohamed Salah
# 2     19        5            1984            82.67      Alexander Isak
# 3     20        2            1927            87.59  Robert Lewandowski
# 4      9       11            1784            89.20       Florian Wirtz
#
#     market_value
# 0   90,00 € Mio.
# 1   55,00 € Mio.
# 2   75,00 € Mio.
# 3   15,00 € Mio.
# 4  140,00 € Mio.

# %%
df_top5_2024 = df_top5_2024.reindex(columns = ['player_name', 'market_value', 'goals', 'assists', 'minutes_played', 'minutes_per_g_a'])

# %%
df_top5_2024
# Out:
#           player_name   market_value  goals  assists  minutes_played  \
# 0          Harry Kane   90,00 € Mio.     21        8            1648
# 1       Mohamed Salah   55,00 € Mio.     25       16            2395
# 2      Alexander Isak   75,00 € Mio.     19        5            1984
# 3  Robert Lewandowski   15,00 € Mio.     20        2            1927
# 4       Florian Wirtz  140,00 € Mio.      9       11            1784
#
#    minutes_per_g_a
# 0            56.83
# 1            58.41
# 2            82.67
# 3            87.59
# 4            89.20

# %% [markdown]
# ### Merge 2022 Top 5 Players Info & Perfomance DataFrames

# %%
df_top5_2022['player_id'] = df_top5_2022['player_id'].astype(int)
df_players_info_2022['player_id'] = df_players_info_2022['player_id'].astype(int)

# %%
df_top5_2022 = pd.merge(df_top5_2022,df_players_info_2022, on = 'player_id', how = 'left')

# %%
df_top5_2022.drop(columns = ['player_id'], inplace = True)

# %%
df_top5_2022
# Out:
#    goals  assists  minutes_played  minutes_per_g_a        player_name  \
# 0     36        8            2777            63.11     Erling Haaland
# 1     29        6            2822            80.63      Kylian Mbappé
# 2     26        5            2581            83.26     Victor Osimhen
# 3     19        6            2128            85.12  Wissam Ben Yedder
# 4     12       13            2211            88.44      Jamal Musiala
#
#     market_value
# 0  200,00 € Mio.
# 1  160,00 € Mio.
# 2   75,00 € Mio.
# 3    4,00 € Mio.
# 4  140,00 € Mio.

# %%
df_top5_2022 = df_top5_2022.reindex(columns = ['player_name', 'market_value', 'goals', 'assists', 'minutes_played', 'minutes_per_g_a'])

# %%
df_top5_2022
# Out:
#          player_name  market_value_in_millions  goals  assists  \
# 0     Erling Haaland                       200     36        8
# 1      Kylian Mbappé                       160     29        6
# 2     Victor Osimhen                        75     26        5
# 3  Wissam Ben Yedder                         4     19        6
# 4      Jamal Musiala                       140     12       13
#
#    minutes_played  minutes_per_g_a
# 0            2777            63.11
# 1            2822            80.63
# 2            2581            83.26
# 3            2128            85.12
# 4            2211            88.44

# %% [markdown]
# #### EDA

# %% [markdown]
# ### Hypothesis 1 - None of the top 5 players will be cheaper than 50M EUR - 2024

# %%
df_top5_2024 = pd.read_csv('df_top5_2024.csv')

# %%
df_top5_2024.dtypes
# Out:
# player_name         object
# market_value        object
# goals                int64
# assists              int64
# minutes_played       int64
# minutes_per_g_a    float64
# dtype: object

# %%
df_top5_2024['market_value'] = df_top5_2024['market_value'].str.replace(',00 € Mio.' , '')

# %%
df_top5_2024.rename(columns={'market_value': 'market_value_in_millions'}, inplace=True)

# %%
df_top5_2024['market_value_in_millions'] = pd.to_numeric(df_top5_2024['market_value_in_millions'], errors='coerce')

# %%
df_top5_2024_under_50m = df_top5_2024[(df_top5_2024['market_value_in_millions'] < 50)]
df_top5_2024_under_50m
# Out:
#           player_name  market_value_in_millions  goals  assists  \
# 3  Robert Lewandowski                        15     20        2
#
#    minutes_played  minutes_per_g_a
# 3            1927            87.59

# %% [markdown]
# ### Further Insight

# %%
df_top5_2022 = pd.read_csv('df_top5_2022.csv')

# %%
df_top5_2022['market_value'] = df_top5_2022['market_value'].str.replace(',00 € Mio.' , '')

# %%
df_top5_2022.rename(columns={'market_value': 'market_value_in_millions'}, inplace=True)

# %%
df_top5_2022
# Out:
#          player_name market_value_in_millions  goals  assists  minutes_played  \
# 0     Erling Haaland                      200     36        8            2777
# 1      Kylian Mbappé                      160     29        6            2822
# 2     Victor Osimhen                       75     26        5            2581
# 3  Wissam Ben Yedder                        4     19        6            2128
# 4      Jamal Musiala                      140     12       13            2211
#
#    minutes_per_g_a
# 0            63.11
# 1            80.63
# 2            83.26
# 3            85.12
# 4            88.44

# %%
df_top5_2022['market_value_in_millions'] = pd.to_numeric(df_top5_2022['market_value_in_millions'], errors='coerce')

# %%
df_top5_2022.dtypes
# Out:
# player_name                  object
# market_value_in_millions      int64
# goals                         int64
# assists                       int64
# minutes_played                int64
# minutes_per_g_a             float64
# dtype: object

# %%
# Market value divided by goals + assists
df_top5_2022_value = df_top5_2022.copy()

df_top5_2022_value['market_value_per_g_a_milions'] = round(df_top5_2022['market_value_in_millions'] / (df_top5_2022['goals'] + df_top5_2022['assists']), 2)

# %%
df_top5_2022_value
# Out:
#          player_name  market_value_in_millions  goals  assists  \
# 0     Erling Haaland                       200     36        8
# 1      Kylian Mbappé                       160     29        6
# 2     Victor Osimhen                        75     26        5
# 3  Wissam Ben Yedder                         4     19        6
# 4      Jamal Musiala                       140     12       13
#
#    minutes_played  minutes_per_g_a  market_value_per_g_a_milions
# 0            2777            63.11                          4.55
# 1            2822            80.63                          4.57
# 2            2581            83.26                          2.42
# 3            2128            85.12                          0.16
# 4            2211            88.44                          5.60

# %%
df_top5_2024_value = df_top5_2024.copy()

df_top5_2024_value['market_value_per_g_a_milions'] = round(df_top5_2024['market_value_in_millions'] / (df_top5_2024['goals'] + df_top5_2024['assists']), 2)

# %%
df_top5_2024_value
# Out:
#           player_name   market_value  goals  assists  minutes_played  \
# 0          Harry Kane   90,00 € Mio.     21        8            1648
# 1       Mohamed Salah   55,00 € Mio.     25       16            2395
# 2      Alexander Isak   75,00 € Mio.     19        5            1984
# 3  Robert Lewandowski   15,00 € Mio.     20        2            1927
# 4       Florian Wirtz  140,00 € Mio.      9       11            1784
#
#    minutes_per_g_a
# 0            56.83
# 1            58.41
# 2            82.67
# 3            87.59
# 4            89.20

# %%
average_value_2024 = df_top5_2024_value['market_value_per_g_a_milions'].mean()
average_value_2024
# Out:
# 3.048

# %%
average_value_2022 = df_top5_2022_value['market_value_per_g_a_milions'].mean()
average_value_2022
# Out:
# 3.46

# %%
value_change_percentage = round((average_value_2024 - average_value_2022) / average_value_2022 * 100, 2)
print(f'{value_change_percentage}%')
# Out:
# -11.91%

# %%
value_change_milions = average_value_2022 - average_value_2024
print(f'€{value_change_milions.round(2)}M')
# Out:
# €0.41M

# %%
average_minutes_per_g_a_2024 = df_top5_2024['minutes_per_g_a'].mean()
average_minutes_per_g_a_2022 = df_top5_2022['minutes_per_g_a'].mean()

# %%
average_minutes_per_ga_diference = average_minutes_per_g_a_2024 - average_minutes_per_g_a_2022
print(f'€{average_minutes_per_ga_diference.round(2)}minutes')
# Out:
# €-5.17minutes

# %%
m_g_a_change_percentage = round((average_minutes_per_g_a_2024 - average_minutes_per_g_a_2022) / average_minutes_per_g_a_2022 * 100, 2)
print(f'{m_g_a_change_percentage}%')
# Out:
# -6.46%

# %% [markdown]
# ### Charts

# %%
df_top5_2024_value
# Out:
#           player_name  market_value_in_millions  goals  assists  \
# 0          Harry Kane                        90     21        8
# 1       Mohamed Salah                        55     25       16
# 2      Alexander Isak                        75     19        5
# 3  Robert Lewandowski                        15     20        2
# 4       Florian Wirtz                       140      9       11
#
#    minutes_played  minutes_per_g_a  market_value_per_g_a_milions
# 0            1648            56.83                          3.10
# 1            2395            58.41                          1.34
# 2            1984            82.67                          3.12
# 3            1927            87.59                          0.68
# 4            1784            89.20                          7.00

# %%
df_marketvalue2024 = df_top5_2024_value.sort_values(by='market_value_in_millions', ascending=True)
# Plot
plt.figure(figsize=(12, 8))
ax = sns.barplot(
    data=df_marketvalue2024,
    x='market_value_in_millions',
    y='player_name',
    palette='Greens_r'
)
plt.xlabel("Market Value (€Ms)")
plt.ylabel("Player Name")
plt.title('Top Players Sorted by Market Value 2024')

for bar in ax.patches:
    plt.text(
        bar.get_width(),              # X coordinate (bar length)
        bar.get_y() + bar.get_height() / 2,  # Y coordinate (center of the bar)
        f'{bar.get_width():.1f}',     # Format the value with 1 decimal place
        va='center',                  # Vertical alignment
        ha='left',                    # Horizontal alignment
        fontsize=10,
        color='black'
    )
plt.show()
# Out:
# C:\Users\estif\AppData\Local\Temp\ipykernel_14136\442436924.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
df_sorted = df_top5_2024_value.sort_values(by='market_value_per_g_a_milions', ascending=True)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=df_sorted,
    x='market_value_per_g_a_milions',
    y='player_name',
    palette='Greens_r'
)

plt.xlabel("Market Value Per Goal/Assist (€Ms)")
plt.ylabel("Player Name")
plt.title('Top Players Sorted by Market Value Per Goal/Assist 2024')

plt.show()
# Out:
# C:\Users\estif\AppData\Local\Temp\ipykernel_16360\2515630795.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
df_minutesperga2024 = df_top5_2024_value.sort_values(by='minutes_per_g_a', ascending=True)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data = df_minutesperga2024,
    x='minutes_per_g_a',
    y='player_name',
    palette='Greens_r'
)

plt.xlabel("Minutes Per Goal/Assist")
plt.ylabel("Player Name")
plt.title("Top Players Sorted by Least Minutes per Goal/Assist 2024")

plt.show()
# Out:
# C:\Users\estif\AppData\Local\Temp\ipykernel_16360\2062005516.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
df_minutesperga2022 = df_top5_2022_value.sort_values(by='minutes_per_g_a', ascending=True)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data = df_minutesperga2022,
    x='minutes_per_g_a',
    y='player_name',
    palette='Greens_r'
)

plt.xlabel("Minutes Per Goal/Assist")
plt.ylabel("Player Name")
plt.title("Top Players Sorted by Least Minutes per Goal/Assist 2022")

plt.show()
# Out:
# C:\Users\estif\AppData\Local\Temp\ipykernel_16360\2323196724.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
print(value_change_percentage)
print(average_value_2024)
print(average_value_2022)
print(f'€{value_change_milions.round(2)}M')
# Out:
# -11.91
# 3.048
# 3.46
# €0.41M

# %%
values = [average_value_2022, average_value_2024]
years = ['2022', '2024']


green_shades = sns.color_palette("Greens_r", as_cmap=True)  
red_shades = sns.color_palette("Reds", as_cmap=True)  


green_color = green_shades(0.3) 
red_color = red_shades(0.7)


colors = [red_color, green_color]


plt.figure(figsize=(6, 4))


sns.barplot(x=years, y=values, palette=colors)


change_text = f"€{value_change_milions.round(2)}M ({value_change_percentage:.2f}%)"
plt.text(1, average_value_2024 + 0.2, change_text, ha='center', fontsize=12, fontweight='bold')


plt.ylabel("Market Value Per G&A (€M)")
plt.xlabel("Year")
plt.title("Market Value Per G&A (2022 vs 2024)")

plt.show()
# Out:
# C:\Users\estif\AppData\Local\Temp\ipykernel_16360\2041477835.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=years, y=values, palette=colors)

# %%
print(average_minutes_per_g_a_2024)
print(average_minutes_per_g_a_2022)
print(average_minutes_per_ga_diference.round(2))
print(f'{m_g_a_change_percentage}%')
# Out:
# 74.94
# 80.112
# -5.17
# -6.46%

# %%
values = [average_minutes_per_g_a_2022, average_minutes_per_g_a_2024]
years = ['2022', '2024']


green_shades = sns.color_palette("Greens_r", as_cmap=True)  
red_shades = sns.color_palette("Reds", as_cmap=True)  


green_color = green_shades(0.3) 
red_color = red_shades(0.7)


colors = [red_color, green_color]


plt.figure(figsize=(6, 4))


sns.barplot(x=years, y=values, palette=colors)


change_text = f"{average_minutes_per_ga_diference.round(2)}minutes ({m_g_a_change_percentage:.2f}%)"

plt.text(1, values[1] + 3, change_text, ha='center', fontsize=10, fontweight='bold')
    

plt.ylabel("AVG Minutes Per G&A")
plt.xlabel("Year")
plt.title("AVG Minutes Per G&A (2022 vs 2024)")

plt.show()
# Out:
# C:\Users\estif\AppData\Local\Temp\ipykernel_16360\415901032.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=years, y=values, palette=colors)
